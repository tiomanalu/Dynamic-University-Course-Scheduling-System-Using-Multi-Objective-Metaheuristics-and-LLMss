# %%
import pandas as pd
import random
import copy
import os
import importlib
import sys
from collections import Counter, defaultdict
from deap import base, creator, tools

# --- Konfigurasi Global ---
DATASET_CATEGORIES = {
    "Low": "JADWAL PERKULIAHAN SEMESTER PENDEK  T.A 23_24 - Jadwal.csv",
    "Medium": "JADWAL PERKULIAHAN SEMESTER GENAP 2023_2024 - Jadwal.csv"
}
DAYS_ORDER = ['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat']

print("✅ Pustaka dan Konfigurasi Awal Siap.")

# ==============================================================================
# BAGIAN 2: FUNGSI-FUNGSI INTI (PARSING, EVALUASI, PREFERENSI)
# ==============================================================================

def parse_schedule_dynamically(file_path):
    """Fungsi parsing CSV yang paling tangguh."""
    try:
        header_df = pd.read_csv(file_path, header=None, nrows=7, engine='python', dtype=str).fillna('')
        day_positions, header_row_index = {}, -1
        for idx, row in header_df.iterrows():
            if any(day in row.astype(str).values for day in DAYS_ORDER): header_row_index = idx; break
        if header_row_index == -1: return None, None, "❌ Error: Tidak dapat menemukan header hari."
        header_series = header_df.iloc[header_row_index]
        for col_idx, value in header_series.items():
            if isinstance(value, str):
                for day in DAYS_ORDER:
                    if day.lower() in value.lower(): day_positions[day] = col_idx; break
        jadwal_df = pd.read_csv(file_path, skiprows=header_row_index + 1, header=None, engine='python', dtype=str).fillna('')
        all_sessions, lecture_schedule, sesi_col, day_cols_template = [], [], 0, ['Kode MK', 'Mata Kuliah', 'T/P', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'I1', 'I2', 'Kelas', 'Ruang']
        for day in DAYS_ORDER:
            if day not in day_positions: continue
            start_col = day_positions[day]
            if start_col + len(day_cols_template) > len(jadwal_df.columns): continue
            day_df = jadwal_df.iloc[:, [sesi_col] + list(range(start_col, start_col + len(day_cols_template)))]
            day_df.columns = ['Sesi'] + day_cols_template
            day_df = day_df[day_df['Kode MK'].str.strip() != '']
            day_df = day_df[pd.to_numeric(day_df['Sesi'], errors='coerce').notna()]
            for idx, row in day_df.iterrows():
                teachers = [str(row[f'D{i}']).strip() for i in range(1, 8) if str(row[f'D{i}']).strip() not in ['', '-']] + \
                           [str(row[f'I{i}']).strip() for i in range(1, 3) if str(row[f'I{i}']).strip() not in ['', '-']]
                if not teachers or not str(row['Kelas']).strip() or not str(row['Ruang']).strip(): continue
                class_id = f"{str(row['Kode MK']).strip()}_{idx}_{str(row['Kelas']).strip()}"
                all_sessions.append({
                    'class_id': class_id,
                    'room': str(row['Ruang']).strip(),
                    'course_id': str(row['Kode MK']).strip(),
                    'teacher1': teachers[0] if teachers else None,
                    'type': str(row['T/P']).strip(),
                    'teacher2': teachers[1] if len(teachers) > 1 else None,
                    'group': str(row['Kelas']).strip(),
                    'day': day,
                    'session': str(row['Sesi']).strip(),
                    'course_name': str(row['Mata Kuliah']).strip()
                })
                lecture_schedule.append([
                    len(lecture_schedule) + 1,  # lecture_id
                    class_id,                   # class_id
                    str(row['Kode MK']).strip(), # course_id
                    teachers[0] if teachers else '0', # teacher_id1
                    teachers[1] if len(teachers) > 1 else '0' # teacher_id2
                ])
        print(f"✅ Berhasil mem-parsing {len(all_sessions)} sesi kuliah valid.")
        return all_sessions, lecture_schedule, None
    except Exception as e:
        return None, None, f"❌ Terjadi kesalahan kritis saat parsing: {e}"

def convert_to_random_schedule(schedule_list):
    """
    Mengonversi schedule_list ke format random_schedule yang BENAR
    untuk dikonsumsi oleh fungsi preferensi buatan AI.
    """
    random_schedule = []
    for session in schedule_list:
        room_id = session.get('room', '0')
        day = session.get('day')
        session_str = session.get('session', '-1')
        group_name = session.get('group', '0')
        course_id = session.get('course_id', '0')
        teacher1 = session.get('teacher1', '0')
        teacher2 = session.get('teacher2', '0')
        day_idx = DAYS_ORDER.index(day) if day in DAYS_ORDER else -1
        session_idx = int(session_str) - 1 if session_str.isdigit() else -1
        random_schedule.append([
            room_id, day_idx, session_idx, group_name, course_id, teacher1, teacher2
        ])
    return random_schedule

def count_hard_conflicts(schedule_list):
    """Mengevaluasi konflik dengan aturan khusus yang telah ditetapkan."""
    room_conflicts, teacher_conflicts, group_conflicts = 0, 0, 0
    slots = defaultdict(list)
    for session in schedule_list: slots[(session['day'], session['session'])].append(session)
    for slot_key, sessions_in_slot in slots.items():
        if len(sessions_in_slot) <= 1: continue
        teacher_events, room_events, group_usage = Counter(), Counter(), Counter()
        events = defaultdict(list)
        for s in sessions_in_slot:
            event_key = (s.get('teacher1'), s.get('room'), s.get('course_id')); events[event_key].append(s); group_usage[s.get('group')] += 1
        for (teacher, room, course), event_sessions in events.items():
            if teacher: teacher_events[teacher] += 1
            if room: room_events[room] += 1
        for teacher, count in teacher_events.items():
            if count > 4: teacher_conflicts += (count - 4)
        for room, count in room_events.items():
            if room == 'AUD':
                if count > 3: room_conflicts += (count - 3)
            elif count > 1: room_conflicts += (count - 1)
        for group, count in group_usage.items():
            if count > 1: group_conflicts += (count - 1)
    return (room_conflicts, teacher_conflicts, group_conflicts)

def generate_preference_function(user_prompt):
    """Mengimpor fungsi preferensi dari file buatan AI."""
    print(f"\nMenggunakan preferensi: '{user_prompt}'")
    print(f"   - Mengimpor fungsi preferensi dari lecturer_preference_function, student_preference_function, institutional_preference_function...")
    try:
        import lecturer_preference_function
        import student_preference_function
        import institutional_preference_function
        importlib.reload(lecturer_preference_function)
        importlib.reload(student_preference_function)
        importlib.reload(institutional_preference_function)
        from lecturer_preference_function import count_preference_conflict as lecturer_conflict
        from student_preference_function import count_preference_conflict as student_conflict
        from institutional_preference_function import count_preference_conflict as institutional_conflict

        def wrapped_preference_function(schedule_list, lecture_schedule):
            random_schedule = convert_to_random_schedule(schedule_list)
            lecturer_score = lecturer_conflict(random_schedule, lecture_schedule)
            student_score = student_conflict(random_schedule, lecture_schedule)
            institutional_score = institutional_conflict(random_schedule, lecture_schedule)
            return lecturer_score, student_score, institutional_score

        print("   - ✅ Fungsi preferensi berhasil diimpor.")
        return wrapped_preference_function, user_prompt
    except Exception as e:
        print(f"   - ❌ Gagal mengimpor fungsi preferensi: {e}.")
        return (lambda s, l: (-1, -1, -1)), user_prompt

# ==============================================================================
# BAGIAN 3: FUNGSI OPTIMISASI DAN ANALISIS
# ==============================================================================

def mutTargeted(individual, preference_function, lecture_schedule, indpb, all_rooms, all_sessions_options):
    """Operator mutasi cerdas yang menargetkan sesi yang konflik."""
    conflicting_indices = [i for i, session in enumerate(individual) if sum(preference_function([session], lecture_schedule)) > 0]

    if not conflicting_indices or random.random() > indpb:
        return mutMoveToEmptySlot(individual, 0.05, all_rooms, all_sessions_options)

    idx_to_move = random.choice(conflicting_indices)
    original_session = individual[idx_to_move]

    occupied_slots = set((s['day'], s['session'], s['room']) for s in individual)

    for _ in range(200):
        new_day, new_session, new_room = random.choice(DAYS_ORDER), random.choice(all_sessions_options), random.choice(all_rooms)
        if (new_day, new_session, new_room) not in occupied_slots:
            individual[idx_to_move]['day'] = new_day
            individual[idx_to_move]['session'] = new_session
            individual[idx_to_move]['room'] = new_room
            return individual,

    return individual,

def mutMoveToEmptySlot(individual, indpb, all_rooms, all_sessions_options):
    """Mutasi acak sebagai cadangan."""
    occupied_slots = set((s['day'], s['session'], s['room']) for s in individual)
    for i in range(len(individual)):
        if random.random() < indpb:
            for _ in range(100):
                new_day, new_session, new_room = random.choice(DAYS_ORDER), random.choice(all_sessions_options), random.choice(all_rooms)
                if (new_day, new_session, new_room) not in occupied_slots:
                    individual[i]['day'], individual[i]['session'], individual[i]['room'] = new_day, new_session, new_room
                    break
    return individual,

def setup_deap_toolbox_nsga3(initial_schedule, lecture_schedule, preference_function):
    """Mempersiapkan toolbox DEAP dengan fungsi evaluasi dan mutasi yang diperbaiki."""
    if hasattr(creator, "FitnessMin"): del creator.FitnessMin
    if hasattr(creator, "Individual"): del creator.Individual
    creator.create("FitnessMin", base.Fitness, weights=(-1.0, -1.0, -1.0, -1.0))  # Hard + 3 soft conflicts
    creator.create("Individual", list, fitness=creator.FitnessMin)
    toolbox = base.Toolbox()
    toolbox.register("individual", tools.initIterate, creator.Individual, lambda: copy.deepcopy(initial_schedule))
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    def evaluate(individual):
        hard_conflicts = sum(count_hard_conflicts(individual))
        lecturer_score, student_score, institutional_score = preference_function(individual, lecture_schedule)
        PENALTY = 10000
        penalized_hard_fitness = hard_conflicts * PENALTY
        return (penalized_hard_fitness, lecturer_score, student_score, institutional_score)
    toolbox.register("evaluate", evaluate)

    toolbox.register("mate", tools.cxTwoPoint)

    all_rooms = list(set(s['room'] for s in initial_schedule))
    all_sessions_options = list(set(s['session'] for s in initial_schedule))

    toolbox.register("mutate", mutTargeted,
                     preference_function=preference_function,
                     lecture_schedule=lecture_schedule,
                     indpb=0.5,
                     all_rooms=all_rooms,
                     all_sessions_options=all_sessions_options)
    
    ref_points = tools.uniform_reference_points(nobj=4, p=12)  # Updated for 4 objectives
    toolbox.register("select", tools.selNSGA3, ref_points=ref_points)
    return toolbox

def run_optimization_nsga3(initial_schedule, lecture_schedule, preference_function, pop_size, generations, cxpb, mutpb):
    """Menjalankan algoritma genetika NSGA-III dengan strategi Elitism yang diperbaiki."""
    toolbox = setup_deap_toolbox_nsga3(initial_schedule, lecture_schedule, preference_function)
    pop = toolbox.population(n=pop_size)
    print("  -> Mengevaluasi populasi awal untuk optimisasi...")
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses): ind.fitness.values = fit

    best_known_individual = copy.deepcopy(tools.selBest(pop, 1)[0])
    if sum(count_hard_conflicts(best_known_individual)) > 0:
        print("⚠️ Peringatan: Jadwal awal yang menjadi dasar elitisme sudah memiliki konflik hard.")

    print(f"\n🚀 Memulai Optimisasi NSGA-III... (Pop: {pop_size}, Gen: {generations}, CX: {cxpb}, Mut: {mutpb})")
    for gen in range(1, generations + 1):
        offspring = toolbox.select(pop, len(pop)); offspring = list(map(toolbox.clone, offspring))
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < cxpb: toolbox.mate(child1, child2); del child1.fitness.values; del child2.fitness.values
        for mutant in offspring:
            if random.random() < mutpb: toolbox.mutate(mutant); del mutant.fitness.values
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]; fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses): ind.fitness.values = fit

        for ind in pop + offspring:
            if sum(ind.fitness.values) < sum(best_known_individual.fitness.values):
                best_known_individual = copy.deepcopy(ind)

        pop[:] = toolbox.select(pop + offspring, pop_size)
        pop[0] = best_known_individual

        best_hard, best_lecturer, best_student, best_institutional = best_known_individual.fitness.values
        best_hard_real = best_hard / 10000

        if gen % 100 == 0:
            print(f"  -> Gen {gen}/{generations} | Solusi Terbaik Sejauh Ini: Hard={int(best_hard_real)}, "
                  f"Lecturer={best_lecturer}, Student={best_student}, Institutional={best_institutional}")
            if best_hard_real == 0 and best_lecturer == 0 and best_student == 0 and best_institutional == 0:
                print("🎉 Solusi optimal (Hard=0, Lecturer=0, Student=0, Institutional=0) ditemukan!"); break

    print("✅ Optimisasi Selesai.")
    return best_known_individual

def analyze_and_compare_schedules(initial_schedule, final_schedule, lecture_schedule, pref_function, user_prompt, category):
    """Menganalisis dan membandingkan jadwal dengan ringkasan yang lebih cerdas."""
    print("\n" + "="*80)
    print(f"ANALISIS KOMPARATIF: JADWAL AWAL vs JADWAL HASIL OPTIMISASI (Kategori: {category})")
    print("="*80)
    initial_hard = sum(count_hard_conflicts(initial_schedule))
    initial_lecturer, initial_student, initial_institutional = pref_function(initial_schedule, lecture_schedule)
    final_hard = sum(count_hard_conflicts(final_schedule))
    final_lecturer, final_student, final_institutional = pref_function(final_schedule, lecture_schedule)
    print(f"\nPreferensi yang dioptimalkan: '{user_prompt}' (Kategori: {category})")
    print(f"\n--- Perbandingan Skor Konflik ---")
    print(f"{'Jenis Konflik':<30} | {'Jadwal Awal':<15} | {'Jadwal Optimasi':<15}")
    print("-" * 70)
    print(f"{'Konflik Hard (Total)':<30} | {initial_hard:<15} | {final_hard:<15}")
    print(f"{'Konflik Dosen':<30} | {initial_lecturer:<15} | {final_lecturer:<15}")
    print(f"{'Konflik Mahasiswa':<30} | {initial_student:<15} | {final_student:<15}")
    print(f"{'Konflik Institusi':<30} | {initial_institutional:<15} | {final_institutional:<15}")
    print("-" * 70)
    print("\n--- Ringkasan ---")
    if final_hard > initial_hard:
        print(f"⚠️ PERINGATAN! Optimisasi menambah {final_hard - initial_hard} konflik hard baru! Hasil ini TIDAK disarankan.")
    elif final_hard < initial_hard:
        print(f"✅ LUAR BIASA! Optimisasi berhasil menghilangkan {initial_hard - final_hard} konflik hard.")
    total_initial_soft = initial_lecturer + initial_student + initial_institutional
    total_final_soft = final_lecturer + final_student + final_institutional
    if final_hard == initial_hard and total_final_soft < total_initial_soft:
        print(f"✅ BAIK! Optimisasi berhasil mengurangi {total_initial_soft - total_final_soft} pelanggaran preferensi tanpa menambah konflik hard.")
    else:
        print("ℹ️ Tidak ada peningkatan signifikan. Jadwal mungkin sudah optimal atau perlu lebih banyak generasi/parameter berbeda.")

def export_final_schedule(final_schedule, category, output_file="optimized_schedule_{category}.csv"):
    """Prints the final schedule with group information and saves it to a CSV file."""
    session_times = {
        '1': '08:00-08:50',
        '2': '09:00-09:50',
        '3': '10:00-10:50',
        '4': '11:00-11:50',
        '5': '13:00-13:50',
        '6': '14:00-14:50',
        '7': '15:00-15:50',
        '8': '16:00-16:50'
    }

    sessions = sorted(set(s['session'] for s in final_schedule if s['session'] in session_times), key=lambda x: int(x))
    schedule_dict = defaultdict(list)
    for session in final_schedule:
        if session['session'] in session_times:
            schedule_dict[(session['day'], session['session'])].append(session)

    print("\n" + "="*80)
    print(f"FINAL OPTIMIZED SCHEDULE (DAFTAR PER HARI) - Kategori: {category}")
    print("="*80)

    for day in DAYS_ORDER:
        print(f"\n{day}:")
        for session in sessions:
            time_slot = session_times[session]
            key = (day, session)
            if key in schedule_dict:
                for s in schedule_dict[key]:
                    teachers = f"{s['teacher1']}" if s['teacher1'] else ""
                    if s['teacher2'] and s['teacher2'] != '0':
                        teachers += f", {s['teacher2']}"
                    info = f"Course {s['course_name']} (Teacher {teachers}, Room {s['room']}, Group {s['group']})"
                    print(f"  - {time_slot} → {info}")
            else:
                print(f"  - {time_slot} → No class scheduled")
    print("="*80)

    df = pd.DataFrame(final_schedule)
    df['time_slot'] = df['session'].map(session_times)
    df['teachers'] = df.apply(
        lambda row: f"{row['teacher1']}" + (f", {row['teacher2']}" if row.get('teacher2') and row['teacher2'] != '0' else ""),
        axis=1
    )
    df['group'] = df['group'].fillna('Unknown')
    output_df = df[['day', 'time_slot', 'course_name', 'teachers', 'room', 'group', 'course_id', 'class_id', 'type']]
    output_file = output_file.format(category=category)
    output_dir = os.path.dirname(output_file)
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)
    try:
        output_df.to_csv(output_file, index=False, encoding='utf-8')
        print(f"\n✅ Schedule successfully saved to '{output_file}'")
    except Exception as e:
        print(f"\n❌ Error saving CSV: {e}")

def main_workflow(category="Low", user_prompt="Default preference"):
    print(f"--- LANGKAH 1: MEMBACA & MEM-PARSING JADWAL AWAL (Kategori: {category}) ---")
    if category not in DATASET_CATEGORIES:
        print(f"❌ Kategori '{category}' tidak valid. Pilih dari {list(DATASET_CATEGORIES.keys())}.")
        return
    file_path = DATASET_CATEGORIES[category]
    schedule_list, lecture_schedule, error = parse_schedule_dynamically(file_path)
    if error:
        print(error)
        return

    (r_conf, t_conf, g_conf) = count_hard_conflicts(schedule_list)
    total_hard_conflicts = r_conf + t_conf + g_conf
    print(f"\nVerifikasi Konflik Hard Awal: Total = {total_hard_conflicts} (Ruang: {r_conf}, Dosen: {t_conf}, Grup: {g_conf})")

    print("\n" + "="*80)
    print(f"--- LANGKAH 2: EVALUASI PREFERENSI (Kategori: {category}) ---")
    print("="*80)

    preference_function, pref_prompt = generate_preference_function(user_prompt)
    lecturer_score, student_score, institutional_score = preference_function(schedule_list, lecture_schedule)
    if lecturer_score >= 0 and student_score >= 0 and institutional_score >= 0:
        print(f"   -> Hasil Verifikasi: Ditemukan pelanggaran untuk preferensi '{pref_prompt}':")
        print(f"      - Konflik Dosen: {lecturer_score}")
        print(f"      - Konflik Mahasiswa: {student_score}")
        print(f"      - Konflik Institusi: {institutional_score}")
    else:
        print(f"   -> ❌ Gagal mengevaluasi preferensi '{pref_prompt}'.")
        return

    print("\n" + "="*80)
    print(f"--- LANGKAH 3: OPTIMISASI JADWAL (Kategori: {category}) ---")
    print("="*80)
    print(f"\n### MEMULAI OPTIMISASI UNTUK PREFERENSI: '{pref_prompt}' (Kategori: {category}) ###")
    final_schedule = run_optimization_nsga3(
        initial_schedule=schedule_list,
        lecture_schedule=lecture_schedule,
        preference_function=preference_function,
        pop_size=200,
        generations=1000,
        cxpb=0.9,
        mutpb=0.3
    )
    if final_schedule:
        analyze_and_compare_schedules(schedule_list, final_schedule, lecture_schedule, preference_function, pref_prompt, category)
        output_file = f"optimized_schedule_{category}.csv"
        export_final_schedule(final_schedule, category, output_file)

    print("\n" + "="*80)
    print(f"PROSES OPTIMISASI DAN EKSPOR JADWAL TELAH SELESAI (Kategori: {category}).")
    print("="*80)

if __name__ == '__main__':
    for category in DATASET_CATEGORIES.keys():
        main_workflow(category=category, user_prompt="Minimize teacher conflicts and prioritize morning sessions")
# Out:
# ✅ Pustaka dan Konfigurasi Awal Siap.
# --- LANGKAH 1: MEMBACA & MEM-PARSING JADWAL AWAL (Kategori: Low) ---
# ✅ Berhasil mem-parsing 144 sesi kuliah valid.
#
# Verifikasi Konflik Hard Awal: Total = 124 (Ruang: 26, Dosen: 0, Grup: 98)
#
# ================================================================================
# --- LANGKAH 2: EVALUASI PREFERENSI (Kategori: Low) ---
# ================================================================================
#
# Menggunakan preferensi: 'Minimize teacher conflicts and prioritize morning sessions'
#    - Mengimpor fungsi preferensi dari lecturer_preference_function, student_preference_function, institutional_preference_function...
#    - ✅ Fungsi preferensi berhasil diimpor.
#    -> Hasil Verifikasi: Ditemukan pelanggaran untuk preferensi 'Minimize teacher conflicts and prioritize morning sessions':
#       - Konflik Dosen: 51
#       - Konflik Mahasiswa: 0
#       - Konflik Institusi: 0
#
# ================================================================================
# --- LANGKAH 3: OPTIMISASI JADWAL (Kategori: Low) ---
# ================================================================================
#
# ### MEMULAI OPTIMISASI UNTUK PREFERENSI: 'Minimize teacher conflicts and prioritize morning sessions' (Kategori: Low) ###
#   -> Mengevaluasi populasi awal untuk optimisasi...
# ⚠️ Peringatan: Jadwal awal yang menjadi dasar elitisme sudah memiliki konflik hard.
#
# 🚀 Memulai Optimisasi NSGA-III... (Pop: 200, Gen: 1000, CX: 0.9, Mut: 0.3)
#   -> Gen 100/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 200/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 300/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 400/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 500/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 600/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 700/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 800/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 900/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
#   -> Gen 1000/1000 | Solusi Terbaik Sejauh Ini: Hard=35, Lecturer=8.0, Student=0.0, Institutional=0.0
# ✅ Optimisasi Selesai.
#
# ================================================================================
# ANALISIS KOMPARATIF: JADWAL AWAL vs JADWAL HASIL OPTIMISASI (Kategori: Low)
# ================================================================================
#
# Preferensi yang dioptimalkan: 'Minimize teacher conflicts and prioritize morning sessions' (Kategori: Low)
#
# --- Perbandingan Skor Konflik ---
# Jenis Konflik                  | Jadwal Awal     | Jadwal Optimasi
# ----------------------------------------------------------------------
# Konflik Hard (Total)           | 124             | 35
# Konflik Dosen                  | 51              | 8
# Konflik Mahasiswa              | 0               | 0
# Konflik Institusi              | 0               | 0
# ----------------------------------------------------------------------
#
# --- Ringkasan ---
# ✅ LUAR BIASA! Optimisasi berhasil menghilangkan 89 konflik hard.
# ℹ️ Tidak ada peningkatan signifikan. Jadwal mungkin sudah optimal atau perlu lebih banyak generasi/parameter berbeda.
#
# ================================================================================
# FINAL OPTIMIZED SCHEDULE (DAFTAR PER HARI) - Kategori: Low
# ================================================================================
#
# Senin:
#   - 08:00-08:50 → Course MADAS II (Teacher REG, 11MR1, Room JUN, Group T)
#   - 09:00-09:50 → Course PBD (Teacher OPH, 41TRPL3, Room ADS, Group T)
#   - 10:00-10:50 → Course MADAS II (Teacher ARS, 11SI2, Room P, Group T)
#   - 11:00-11:50 → Course MADAS I (Teacher JUN, JAS, Room FST, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher ARS, 11SI1, Room AMS, Group T)
#   - 14:00-14:50 → Course MADAS II (Teacher REG, 11TB, Room P, Group T)
#   - 15:00-15:50 → Course MADAS II (Teacher ARS, 11IF2, Room OPH, Group T)
#   - 16:00-16:50 → Course MADAS II (Teacher REG, 11MR2, Room JUN, Group T)
#
# Selasa:
#   - 08:00-08:50 → Course MADAS II (Teacher ARS, 11IF2, Room FBA, Group MADAS II)
#   - 08:00-08:50 → Course MADAS II (Teacher ARS, 11TE2, Room AMP, Group T)
#   - 08:00-08:50 → Course MADAS II (Teacher REG, 11MR1, Room JUN, Group T)
#   - 08:00-08:50 → Course MADAS II (Teacher REG, 11TB, Room JUN, Group T)
#   - 09:00-09:50 → Course INDIG (Teacher RIS, 41TRPL3, Room OPH, Group T)
#   - 09:00-09:50 → Course MADAS II (Teacher REG, 11MR1, Room JUN, Group T)
#   - 09:00-09:50 → Course MADAS II (Teacher REG, 11MR2, Room JUN, Group T)
#   - 09:00-09:50 → Course MADAS II (Teacher REG, 11TB, Room JUN, Group T)
#   - 09:00-09:50 → Course MADAS I (Teacher JUN, JAS, Room FST, Group T)
#   - 10:00-10:50 → Course AOK (Teacher FST, 41TRPL3, Room ADS, Group P)
#   - 10:00-10:50 → Course MADAS I (Teacher AMP, SML, Room ARS, Group T)
#   - 10:00-10:50 → Course MADAS I (Teacher AMP, SML, Room ARS, Group T)
#   - 10:00-10:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 10:00-10:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 10:00-10:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 10:00-10:50 → Course IMM (Teacher GPS, 13TE1, Room GPS, Group T)
#   - 11:00-11:50 → Course MADAS II (Teacher REG, 11TB, Room GPS, Group MADAS II)
#   - 11:00-11:50 → Course MADAS I (Teacher JUN, JAS, Room HMN, Group MADAS I)
#   - 11:00-11:50 → Course AOK (Teacher FST, 41TRPL3, Room ADS, Group P)
#   - 11:00-11:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 13:00-13:50 → Course TA II (Teacher AMS, 44TRPL3, Room AMS, Group P)
#   - 13:00-13:50 → Course MADAS I (Teacher AMP, SML, Room OPH, Group T)
#   - 14:00-14:50 → Course MADAS I (Teacher JUN, JAS, Room T, Group MADAS I)
#   - 14:00-14:50 → Course MADAS I (Teacher JUN, JAS, Room P, Group T)
#   - 14:00-14:50 → Course TA II (Teacher AMS, 44TRPL3, Room AMS, Group P)
#   - 14:00-14:50 → Course MADAS I (Teacher AMP, SML, Room ADS, Group T)
#   - 15:00-15:50 → Course INDIG (Teacher RIS, 41TRPL3, Room ARS, Group AOK)
#   - 15:00-15:50 → Course MADAS II (Teacher ARS, 11SI2, Room REG, Group T)
#   - 15:00-15:50 → Course INDIG (Teacher RIS, 41TRPL3, Room OPH, Group P)
#   - 15:00-15:50 → Course MADAS I (Teacher JUN, JAS, Room T, Group T)
#   - 15:00-15:50 → Course MADAS II (Teacher REG, 11TM, Room ADS, Group T)
#   - 16:00-16:50 → Course PA I (Teacher ADS, 41TRPL3, Room FST, Group AOK)
#   - 16:00-16:50 → Course MADAS II (Teacher REG, 11TM, Room ADS, Group T)
#
# Rabu:
#   - 08:00-08:50 → Course FENOPOR (Teacher MMK, 13TB, Room FST, Group FENOPOR)
#   - 08:00-08:50 → Course MADAS I (Teacher JUN, JAS, Room T, Group MADAS I)
#   - 08:00-08:50 → Course TA II (Teacher AMS, 44TRPL3, Room FBA, Group TA II)
#   - 08:00-08:50 → Course TA II (Teacher AMS, 44TRPL3, Room AMP, Group T)
#   - 08:00-08:50 → Course MADAS I (Teacher JUN, JAS, Room ARS, Group T)
#   - 08:00-08:50 → Course MADAS I (Teacher AMP, SML, Room ADS, Group T)
#   - 08:00-08:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 08:00-08:50 → Course TA II (Teacher AMS, 44TRPL3, Room AMS, Group P)
#   - 09:00-09:50 → Course MADAS II (Teacher ARS, 11TE1, Room GPS, Group MADAS II)
#   - 09:00-09:50 → Course PBD (Teacher OPH, 41TRPL3, Room FST, Group P)
#   - 09:00-09:50 → Course MADAS I (Teacher AMP, SML, Room ARS, Group T)
#   - 09:00-09:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 09:00-09:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 09:00-09:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 10:00-10:50 → Course MADAS I (Teacher JUN, JAS, Room JUN, Group MADAS I)
#   - 10:00-10:50 → Course PA I (Teacher ADS, 41TRPL3, Room ADS, Group P)
#   - 10:00-10:50 → Course ATI (Teacher HMN, 44TRPL3, Room AMS, Group T)
#   - 11:00-11:50 → Course MADAS II (Teacher ARS, 11TE2, Room HMN, Group MADAS II)
#   - 11:00-11:50 → Course MADAS I (Teacher AMP, SML, Room OPH, Group MADAS I)
#   - 11:00-11:50 → Course MADAS II (Teacher ARS, 11TE2, Room GPS, Group T)
#   - 11:00-11:50 → Course PA I (Teacher ADS, 41TRPL3, Room ADS, Group P)
#   - 13:00-13:50 → Course MADAS II (Teacher REG, 11MR2, Room REG, Group MADAS II)
#   - 13:00-13:50 → Course INDIG (Teacher RIS, 41TRPL3, Room GPS, Group PBD)
#   - 13:00-13:50 → Course MADAS II (Teacher REG, 11TB, Room OPH, Group T)
#   - 14:00-14:50 → Course MADAS II (Teacher REG, 11MR1, Room FBA, Group MADAS II)
#   - 14:00-14:50 → Course MADAS I (Teacher JUN, SML, Room ARS, Group MADAS I)
#   - 14:00-14:50 → Course MADAS I (Teacher JUN, JAS, Room GPS, Group T)
#   - 14:00-14:50 → Course IMM (Teacher GPS, 13TE2, Room REG, Group T)
#   - 14:00-14:50 → Course AOK (Teacher FST, 41TRPL3, Room OPH, Group P)
#   - 15:00-15:50 → Course MADAS II (Teacher REG, 11TM, Room FBA, Group MADAS II)
#   - 15:00-15:50 → Course MADAS I (Teacher JUN, SML, Room T, Group T)
#   - 16:00-16:50 → Course MADAS I (Teacher JUN, JAS, Room FBA, Group MADAS I)
#   - 16:00-16:50 → Course PA I (Teacher ADS, 41TRPL3, Room FST, Group INDIG)
#   - 16:00-16:50 → Course MADAS I (Teacher JUN, JAS, Room JUN, Group T)
#   - 16:00-16:50 → Course MADAS I (Teacher JUN, JAS, Room AMP, Group T)
#
# Kamis:
#   - 08:00-08:50 → Course MADAS I (Teacher JUN, SML, Room T, Group MADAS I)
#   - 08:00-08:50 → Course MADAS I (Teacher JUN, JAS, Room FBA, Group T)
#   - 08:00-08:50 → Course MADAS II (Teacher ARS, 11SI2, Room JUN, Group T)
#   - 08:00-08:50 → Course MADAS II (Teacher ARS, 11TE1, Room AMP, Group T)
#   - 08:00-08:50 → Course MADAS II (Teacher ARS, 11TE2, Room AMP, Group T)
#   - 08:00-08:50 → Course TA II (Teacher AMS, 44TRPL3, Room AMS, Group P)
#   - 09:00-09:50 → Course MADAS I (Teacher AMP, SML, Room ARS, Group MADAS I)
#   - 09:00-09:50 → Course MADAS II (Teacher REG, 11TB, Room JUN, Group T)
#   - 10:00-10:50 → Course IMM (Teacher GPS, 13TE1, Room GPS, Group IMM)
#   - 10:00-10:50 → Course PA I (Teacher ADS, 41TRPL3, Room AMP, Group INDIG)
#   - 10:00-10:50 → Course IMM (Teacher GPS, 13TE2, Room OPH, Group T)
#   - 10:00-10:50 → Course PA I (Teacher ADS, 41TRPL3, Room ADS, Group P)
#   - 10:00-10:50 → Course KUPEL (Teacher AMS, 44TRPL3, Room HMN, Group T)
#   - 11:00-11:50 → Course IMM (Teacher GPS, 13TE1, Room REG, Group IMM)
#   - 11:00-11:50 → Course MADAS I (Teacher AMP, SML, Room HMN, Group T)
#   - 11:00-11:50 → Course MADAS I (Teacher AMP, SML, Room GPS, Group T)
#   - 11:00-11:50 → Course PA I (Teacher ADS, 41TRPL3, Room ADS, Group P)
#   - 13:00-13:50 → Course MADAS II (Teacher ARS, 11IF2, Room ARS, Group MADAS II)
#   - 13:00-13:50 → Course MADAS I (Teacher JUN, JAS, Room HMN, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher ARS, 11TE1, Room REG, Group T)
#   - 14:00-14:50 → Course AOK (Teacher FST, 41TRPL3, Room JUN, Group PA I)
#   - 14:00-14:50 → Course MADAS II (Teacher REG, 11TB, Room ADS, Group MADAS II)
#   - 14:00-14:50 → Course MADAS II (Teacher ARS, 11TE1, Room P, Group T)
#   - 14:00-14:50 → Course MADAS I (Teacher JUN, JAS, Room OPH, Group T)
#   - 14:00-14:50 → Course TA II (Teacher AMS, 44TRPL3, Room REG, Group P)
#   - 15:00-15:50 → Course MADAS II (Teacher ARS, 11TE1, Room AMS, Group MADAS II)
#   - 15:00-15:50 → Course MADAS I (Teacher AMP, SML, Room JUN, Group T)
#   - 16:00-16:50 → Course MADAS II (Teacher ARS, 11IF1, Room JUN, Group MADAS II)
#   - 16:00-16:50 → Course MADAS II (Teacher ARS, 11SI1, Room FST, Group T)
#   - 16:00-16:50 → Course AOK (Teacher FST, 41TRPL3, Room REG, Group P)
#
# Jumat:
#   - 08:00-08:50 → Course MADAS II (Teacher ARS, 11SI1, Room FBA, Group MADAS II)
#   - 08:00-08:50 → Course INDIG (Teacher RIS, 41TRPL3, Room REG, Group P)
#   - 08:00-08:50 → Course MADAS II (Teacher REG, 11MR2, Room JUN, Group T)
#   - 09:00-09:50 → Course PBD (Teacher OPH, 41TRPL3, Room REG, Group INDIG)
#   - 09:00-09:50 → Course MADAS II (Teacher ARS, 11SI2, Room JUN, Group MADAS II)
#   - 09:00-09:50 → Course MADAS I (Teacher JUN, JAS, Room GPS, Group MADAS I)
#   - 09:00-09:50 → Course MADAS II (Teacher REG, 11TB, Room AMP, Group T)
#   - 10:00-10:50 → Course MADAS II (Teacher REG, 11MR1, Room GPS, Group MADAS II)
#   - 10:00-10:50 → Course IMM (Teacher GPS, 13TE2, Room AMP, Group IMM)
#   - 10:00-10:50 → Course MADAS I (Teacher AMP, SML, Room T, Group MADAS I)
#   - 10:00-10:50 → Course MADAS II (Teacher ARS, 11SI1, Room JUN, Group T)
#   - 10:00-10:50 → Course MADAS I (Teacher JUN, JAS, Room REG, Group T)
#   - 10:00-10:50 → Course KUPEL (Teacher AMS, 44TRPL3, Room FST, Group P)
#   - 10:00-10:50 → Course MADAS II (Teacher ARS, 11SI2, Room P, Group T)
#   - 11:00-11:50 → Course MADAS II (Teacher ARS, 11TE2, Room FBA, Group MADAS II)
#   - 11:00-11:50 → Course MADAS II (Teacher REG, 11MR2, Room REG, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher ARS, 11IF1, Room GPS, Group MADAS II)
#   - 13:00-13:50 → Course MADAS I (Teacher JUN, SML, Room JUN, Group MADAS I)
#   - 13:00-13:50 → Course FENOPOR (Teacher MMK, 13TB, Room ADS, Group FENOPOR)
#   - 13:00-13:50 → Course MADAS II (Teacher ARS, 11IF1, Room T, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher ARS, 11SI1, Room P, Group T)
#   - 14:00-14:50 → Course MADAS II (Teacher REG, 11MR2, Room P, Group MADAS II)
#   - 14:00-14:50 → Course MADAS I (Teacher AMP, SML, Room FBA, Group MADAS I)
#   - 14:00-14:50 → Course IMM (Teacher GPS, 13TE2, Room AMP, Group IMM)
#   - 14:00-14:50 → Course INDIG (Teacher RIS, 41TRPL3, Room JUN, Group PBD)
#   - 14:00-14:50 → Course MADAS I (Teacher AMP, SML, Room GPS, Group T)
#   - 15:00-15:50 → Course MADAS II (Teacher ARS, 11SI2, Room P, Group MADAS II)
#   - 15:00-15:50 → Course MADAS I (Teacher AMP, SML, Room GPS, Group MADAS I)
#   - 15:00-15:50 → Course TA II (Teacher AMS, 44TRPL3, Room T, Group TA II)
#   - 15:00-15:50 → Course MADAS I (Teacher JUN, SML, Room HMN, Group T)
#   - 15:00-15:50 → Course MADAS II (Teacher ARS, 11TE2, Room REG, Group T)
#   - 16:00-16:50 → Course TA II (Teacher AMS, 44TRPL3, Room ARS, Group TA II)
#   - 16:00-16:50 → Course MADAS II (Teacher ARS, 11SI1, Room AMP, Group MADAS II)
#   - 16:00-16:50 → Course MADAS I (Teacher JUN, SML, Room AMS, Group MADAS I)
#   - 16:00-16:50 → Course MADAS II (Teacher ARS, 11TE1, Room ADS, Group T)
#   - 16:00-16:50 → Course IMM (Teacher GPS, 13TE1, Room T, Group T)
#   - 16:00-16:50 → Course AOK (Teacher FST, 41TRPL3, Room FST, Group P)
#   - 16:00-16:50 → Course MADAS II (Teacher REG, 11MR1, Room FBA, Group T)
# ================================================================================
#
# ✅ Schedule successfully saved to 'optimized_schedule_Low.csv'
#
# ================================================================================
# PROSES OPTIMISASI DAN EKSPOR JADWAL TELAH SELESAI (Kategori: Low).
# ================================================================================
# --- LANGKAH 1: MEMBACA & MEM-PARSING JADWAL AWAL (Kategori: Medium) ---
# ✅ Berhasil mem-parsing 810 sesi kuliah valid.
#
# Verifikasi Konflik Hard Awal: Total = 803 (Ruang: 59, Dosen: 0, Grup: 744)
#
# ================================================================================
# --- LANGKAH 2: EVALUASI PREFERENSI (Kategori: Medium) ---
# ================================================================================
#
# Menggunakan preferensi: 'Minimize teacher conflicts and prioritize morning sessions'
#    - Mengimpor fungsi preferensi dari lecturer_preference_function, student_preference_function, institutional_preference_function...
#    - ✅ Fungsi preferensi berhasil diimpor.
#    -> Hasil Verifikasi: Ditemukan pelanggaran untuk preferensi 'Minimize teacher conflicts and prioritize morning sessions':
#       - Konflik Dosen: 222
#       - Konflik Mahasiswa: 2
#       - Konflik Institusi: 0
#
# ================================================================================
# --- LANGKAH 3: OPTIMISASI JADWAL (Kategori: Medium) ---
# ================================================================================
#
# ### MEMULAI OPTIMISASI UNTUK PREFERENSI: 'Minimize teacher conflicts and prioritize morning sessions' (Kategori: Medium) ###
#   -> Mengevaluasi populasi awal untuk optimisasi...
# ⚠️ Peringatan: Jadwal awal yang menjadi dasar elitisme sudah memiliki konflik hard.
#
# 🚀 Memulai Optimisasi NSGA-III... (Pop: 200, Gen: 1000, CX: 0.9, Mut: 0.3)
#   -> Gen 100/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=108.0, Student=2.0, Institutional=0.0
#   -> Gen 200/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=19.0, Student=2.0, Institutional=0.0
#   -> Gen 300/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=18.0, Student=2.0, Institutional=0.0
#   -> Gen 400/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=18.0, Student=2.0, Institutional=0.0
#   -> Gen 500/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=18.0, Student=2.0, Institutional=0.0
#   -> Gen 600/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=18.0, Student=2.0, Institutional=0.0
#   -> Gen 700/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=18.0, Student=2.0, Institutional=0.0
#   -> Gen 800/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=18.0, Student=2.0, Institutional=0.0
#   -> Gen 900/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=18.0, Student=2.0, Institutional=0.0
#   -> Gen 1000/1000 | Solusi Terbaik Sejauh Ini: Hard=720, Lecturer=18.0, Student=2.0, Institutional=0.0
# ✅ Optimisasi Selesai.
#
# ================================================================================
# ANALISIS KOMPARATIF: JADWAL AWAL vs JADWAL HASIL OPTIMISASI (Kategori: Medium)
# ================================================================================
#
# Preferensi yang dioptimalkan: 'Minimize teacher conflicts and prioritize morning sessions' (Kategori: Medium)
#
# --- Perbandingan Skor Konflik ---
# Jenis Konflik                  | Jadwal Awal     | Jadwal Optimasi
# ----------------------------------------------------------------------
# Konflik Hard (Total)           | 803             | 720
# Konflik Dosen                  | 222             | 18
# Konflik Mahasiswa              | 2               | 2
# Konflik Institusi              | 0               | 0
# ----------------------------------------------------------------------
#
# --- Ringkasan ---
# ✅ LUAR BIASA! Optimisasi berhasil menghilangkan 83 konflik hard.
# ℹ️ Tidak ada peningkatan signifikan. Jadwal mungkin sudah optimal atau perlu lebih banyak generasi/parameter berbeda.
#
# ================================================================================
# FINAL OPTIMIZED SCHEDULE (DAFTAR PER HARI) - Kategori: Medium
# ================================================================================
#
# Senin:
#   - 08:00-08:50 → Course PAM (Teacher ADS, TAP, Room IUS, Group P)
#   - 08:00-08:50 → Course TEKNO (Teacher WMS, 14IF1, Room ADS, Group T)
#   - 09:00-09:50 → Course DETING (Teacher RIS, 43TRPL2, Room RIS, Group P)
#   - 09:00-09:50 → Course EPROF (Teacher ANA, 14MR1, Room WMS, Group T)
#   - 10:00-10:50 → Course PNKI (Teacher TLG, 11TB, Room YAG, Group T)
#   - 10:00-10:50 → Course KOMDAT (Teacher IPM, 33TK1, Room RCH, Group P)
#   - 11:00-11:50 → Course PAM (Teacher HTO, RDS, Room ASD, Group T)
#   - 11:00-11:50 → Course PBD (Teacher HER, RAS, Room HSS, Group P)
#   - 13:00-13:50 → Course PROG  II (Teacher GPS, 12TE2, Room DPL, Group T)
#   - 13:00-13:50 → Course LABTEK (Teacher TML, 13TB, Room TML, Group P)
#   - 14:00-14:50 → Course SISMIK (Teacher ARH, 13TE1, Room IHT, Group T)
#   - 14:00-14:50 → Course LABTEK (Teacher TML, 13TB, Room TML, Group P)
#   - 15:00-15:50 → Course JARKOM (Teacher DPL, ABS, Room ASD, Group T)
#   - 15:00-15:50 → Course LABTEK (Teacher TML, 13TB, Room TML, Group P)
#   - 16:00-16:50 → Course TA I (Teacher RDS, 14IF1, Room RDP, Group T)
#   - 16:00-16:50 → Course SISTER (Teacher ESS, SFN, Room MMK, Group P)
#
# Selasa:
#   - 08:00-08:50 → Course PBO (Teacher ADS, 42TRPL1, Room JBJ, Group P)
#   - 08:00-08:50 → Course MADAS II (Teacher YAG, ARS, Room MMS, Group T)
#   - 08:00-08:50 → Course ABD (Teacher GHP, RCH, Room ARH, Group P)
#   - 08:00-08:50 → Course TA I/II (Teacher PAT, 14SI1, Room ISW, Group T)
#   - 08:00-08:50 → Course TA I/II (Teacher PAT, 14SI2, Room NMA, Group T)
#   - 08:00-08:50 → Course AKPL (Teacher VES, 41TRPL1, Room VES, Group P)
#   - 08:00-08:50 → Course DASPRO (Teacher OPH, 41TRPL3, Room AMS, Group P)
#   - 08:00-08:50 → Course FISDAS IIB (Teacher NMA, 11IF2, Room ACB, Group T)
#   - 08:00-08:50 → Course MADAS II (Teacher ASH, ARS, Room AMP, Group T)
#   - 08:00-08:50 → Course PAR (Teacher IHT, 11TE2, Room RMS, Group T)
#   - 08:00-08:50 → Course PIE (Teacher ANA, FIS, Room GDE, Group P)
#   - 08:00-08:50 → Course PA II (Teacher IFY, 32TI1, Room RCH, Group P)
#   - 08:00-08:50 → Course PA II (Teacher IFY, 32TI2, Room RCH, Group P)
#   - 08:00-08:50 → Course TA II (Teacher HER, 33TI2, Room JYD, Group T)
#   - 08:00-08:50 → Course DETING (Teacher RIS, THL, Room GIW, Group T)
#   - 08:00-08:50 → Course KEPAL (Teacher JHS, 13IF1, Room ASD, Group P)
#   - 08:00-08:50 → Course ERP (Teacher PAT, SRT, Room SGS, Group T)
#   - 08:00-08:50 → Course ERP (Teacher PAT, SRT, Room SGS, Group T)
#   - 08:00-08:50 → Course CERTAN (Teacher GPS, DPL, Room RMM, Group T)
#   - 08:00-08:50 → Course LABTEK (Teacher TML, 13TB, Room FBA, Group T)
#   - 08:00-08:50 → Course TA II (Teacher ADS, 44TRPL2, Room ADS, Group P)
#   - 08:00-08:50 → Course TA II (Teacher RDS, 14IF2, Room RDS, Group P)
#   - 08:00-08:50 → Course TEKEU (Teacher WMS, 14MR2, Room SHT, Group T)
#   - 08:00-08:50 → Course KP (Teacher GIW, FST, Room OPH, Group T)
#   - 08:00-08:50 → Course PBD (Teacher VES, AMS, Room ABS, Group P)
#   - 08:00-08:50 → Course JARKOM (Teacher DPL, ABS, Room TLG, Group T)
#   - 08:00-08:50 → Course REMU (Teacher HSS, 13MR1, Room MMK, Group P)
#   - 08:00-08:50 → Course PA III (Teacher RIS, 43TRPL2, Room HTS, Group P)
#   - 09:00-09:50 → Course LABTEK (Teacher TML, 13TB, Room ESS, Group P)
#   - 09:00-09:50 → Course ELKA I (Teacher DPL, ARH, Room IHT, Group P)
#   - 09:00-09:50 → Course TEKNO (Teacher RIS, 44TRPL1, Room SML, Group P)
#   - 09:00-09:50 → Course ELKA I (Teacher DPL, ARH, Room AMS, Group P)
#   - 09:00-09:50 → Course ELKA I (Teacher DPL, ARH, Room NMA, Group P)
#   - 09:00-09:50 → Course PIE (Teacher ANA, FIS, Room MPR, Group P)
#   - 09:00-09:50 → Course TA I (Teacher RDS, 14IF1, Room SFA, Group P)
#   - 09:00-09:50 → Course PPL (Teacher HER, 31TI2, Room HER, Group P)
#   - 09:00-09:50 → Course PBD (Teacher VES, AMS, Room VES, Group P)
#   - 09:00-09:50 → Course PBD (Teacher VES, AMS, Room VES, Group P)
#   - 09:00-09:50 → Course FISDAS IIB (Teacher NMA, 11IF2, Room ACB, Group T)
#   - 09:00-09:50 → Course MADAS II (Teacher ASH, ARS, Room AMP, Group T)
#   - 09:00-09:50 → Course MADAS II (Teacher ASH, ARS, Room AMP, Group T)
#   - 09:00-09:50 → Course PAR (Teacher IHT, 11TE2, Room RMS, Group T)
#   - 09:00-09:50 → Course PIE (Teacher ANA, FIS, Room GDE, Group P)
#   - 09:00-09:50 → Course PIE (Teacher ANA, FIS, Room GDE, Group P)
#   - 09:00-09:50 → Course FISDAS IIB (Teacher NMA, ISW, Room REG, Group T)
#   - 09:00-09:50 → Course PA II (Teacher IFY, 32TI1, Room RCH, Group P)
#   - 09:00-09:50 → Course PA II (Teacher IFY, 32TI2, Room RCH, Group P)
#   - 09:00-09:50 → Course SISTER (Teacher ESS, 32TK1, Room FST, Group P)
#   - 09:00-09:50 → Course SISOP (Teacher HTO, CHP, Room ASH, Group T)
#   - 09:00-09:50 → Course SISOP (Teacher HTO, CHP, Room ASH, Group T)
#   - 09:00-09:50 → Course PEMPRO (Teacher JBJ, 12MR2, Room ISW, Group T)
#   - 09:00-09:50 → Course DETING (Teacher RIS, THL, Room GIW, Group T)
#   - 09:00-09:50 → Course ERP (Teacher PAT, SRT, Room SGS, Group T)
#   - 09:00-09:50 → Course CERTAN (Teacher GPS, DPL, Room RMM, Group T)
#   - 09:00-09:50 → Course RELOG (Teacher NSS, 13MR2, Room WMS, Group T)
#   - 09:00-09:50 → Course LABTEK (Teacher TML, 13TB, Room FBA, Group T)
#   - 09:00-09:50 → Course KUPEL (Teacher AMS, 44TRPL1, Room ADS, Group P)
#   - 09:00-09:50 → Course KUPEL (Teacher AMS, 44TRPL2, Room ADS, Group P)
#   - 09:00-09:50 → Course TA I (Teacher RDS, 14IF1, Room RDS, Group P)
#   - 09:00-09:50 → Course KP (Teacher GIW, FST, Room SRT, Group T)
#   - 10:00-10:50 → Course BUSNOV (Teacher NSS, 14MR1, Room ASH, Group T)
#   - 10:00-10:50 → Course SISTAN (Teacher FST, IPM, Room TLG, Group P)
#   - 10:00-10:50 → Course AKPL (Teacher VES, 41TRPL2, Room ACB, Group P)
#   - 10:00-10:50 → Course PABI (Teacher MMS, 31TK1, Room RMM, Group P)
#   - 10:00-10:50 → Course PABI (Teacher MMS, 31TK2, Room RMM, Group P)
#   - 10:00-10:50 → Course AKPL (Teacher VES, MEP, Room OPH, Group P)
#   - 10:00-10:50 → Course AKPL (Teacher VES, 41TRPL3, Room ADS, Group P)
#   - 10:00-10:50 → Course FISDAS IIB (Teacher GDE, ISW, Room GDE, Group P)
#   - 10:00-10:50 → Course FISDAS IIB (Teacher GDE, ISW, Room GDE, Group P)
#   - 10:00-10:50 → Course MADAS II (Teacher YAG, 11TB, Room YAG, Group T)
#   - 10:00-10:50 → Course ING IV (Teacher MPR, 32TI1, Room IFY, Group P)
#   - 10:00-10:50 → Course ING IV (Teacher MPR, 32TI2, Room IFY, Group P)
#   - 10:00-10:50 → Course PROBSTAT (Teacher AMP, 42TRPL1, Room AMP, Group P)
#   - 10:00-10:50 → Course PBO (Teacher CHP, AMS, Room DPL, Group P)
#   - 10:00-10:50 → Course GEN BIMOL (Teacher MMM, 12TB, Room NJT, Group T)
#   - 10:00-10:50 → Course PM (Teacher ASD, RSL, Room HTO, Group T)
#   - 10:00-10:50 → Course PM (Teacher ASD, RSL, Room HTO, Group T)
#   - 10:00-10:50 → Course PSD (Teacher GFP, PHI, Room ARH, Group T)
#   - 10:00-10:50 → Course PSD (Teacher GFP, PHI, Room ARH, Group T)
#   - 10:00-10:50 → Course SM/SP (Teacher RIS, 44TRPL3, Room RIS, Group P)
#   - 10:00-10:50 → Course UI/UX (Teacher IUS, SEP, Room -, Group T)
#   - 10:00-10:50 → Course UI/UX (Teacher IUS, SEP, Room -, Group T)
#   - 10:00-10:50 → Course UI/UX (Teacher IUS, SEP, Room RSL, Group P)
#   - 10:00-10:50 → Course LOGEO (Teacher NSS, 14MR2, Room RDP, Group T)
#   - 10:00-10:50 → Course TEKNO (Teacher WMS, 14TB, Room MMM, Group T)
#   - 10:00-10:50 → Course ENG II (Teacher RMS, 11IF1, Room RCH, Group P)
#   - 10:00-10:50 → Course PBD (Teacher HER, RAS, Room JBJ, Group P)
#   - 10:00-10:50 → Course LOGEO (Teacher NSS, 14MR2, Room GIW, Group P)
#   - 11:00-11:50 → Course ABD (Teacher GHP, RCH, Room RMM, Group P)
#   - 11:00-11:50 → Course TA II (Teacher RDS, 14IF2, Room JBJ, Group T)
#   - 11:00-11:50 → Course ERP (Teacher PAT, SRT, Room TLG, Group T)
#   - 11:00-11:50 → Course DP (Teacher GFP, HTO, Room ESS, Group T)
#   - 11:00-11:50 → Course PROG  II (Teacher GPS, 12TE2, Room IHT, Group T)
#   - 11:00-11:50 → Course PAM (Teacher ADS, TAP, Room ASD, Group T)
#   - 11:00-11:50 → Course PEMPRO (Teacher JBJ, 12MR1, Room JUN, Group T)
#   - 11:00-11:50 → Course AKPL (Teacher VES, MEP, Room OPH, Group P)
#   - 11:00-11:50 → Course AKPL (Teacher VES, MEP, Room OPH, Group P)
#   - 11:00-11:50 → Course MADAS II (Teacher YAG, 11TB, Room YAG, Group T)
#   - 11:00-11:50 → Course ING IV (Teacher MPR, 32TI1, Room IFY, Group P)
#   - 11:00-11:50 → Course ING IV (Teacher MPR, 32TI2, Room IFY, Group P)
#   - 11:00-11:50 → Course PLSJ (Teacher MMS, 32TK1, Room MMS, Group P)
#   - 11:00-11:50 → Course PBO (Teacher CHP, AMS, Room DPL, Group P)
#   - 11:00-11:50 → Course PBO (Teacher CHP, AMS, Room DPL, Group P)
#   - 11:00-11:50 → Course SM/SP (Teacher RIS, OPH, Room RIS, Group P)
#   - 11:00-11:50 → Course SM/SP (Teacher RIS, OPH, Room RIS, Group P)
#   - 11:00-11:50 → Course SM/SP (Teacher RIS, 44TRPL3, Room RIS, Group P)
#   - 11:00-11:50 → Course UI/UX (Teacher IUS, SEP, Room -, Group T)
#   - 11:00-11:50 → Course UI/UX (Teacher IUS, SEP, Room -, Group T)
#   - 11:00-11:50 → Course UI/UX (Teacher IUS, SEP, Room RSL, Group P)
#   - 11:00-11:50 → Course LOGEO (Teacher NSS, 14MR1, Room RDP, Group T)
#   - 11:00-11:50 → Course LOGEO (Teacher NSS, 14MR2, Room RDP, Group T)
#   - 11:00-11:50 → Course MANPRO (Teacher NSS, 14TB, Room GDE, Group T)
#   - 11:00-11:50 → Course MATDIS (Teacher AMP, 11SI2, Room AGA, Group T)
#   - 11:00-11:50 → Course SISOP (Teacher HTO, CHP, Room TAP, Group T)
#   - 11:00-11:50 → Course FISDAS IIA (Teacher AFS, 11TE1, Room HSS, Group T)
#   - 11:00-11:50 → Course ADL (Teacher BSS, 14IF2, Room TML, Group T)
#   - 11:00-11:50 → Course PABI (Teacher MMS, MEP, Room IPM, Group P)
#   - 11:00-11:50 → Course MADAS II (Teacher YAG, ARS, Room ACB, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher REG, 11MR2, Room JBJ, Group T)
#   - 13:00-13:50 → Course TA I/II (Teacher PAT, 14SI1, Room FBA, Group T)
#   - 13:00-13:50 → Course PA III (Teacher RIS, 43TRPL1, Room GIW, Group T)
#   - 13:00-13:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room GHP, Group P)
#   - 13:00-13:50 → Course PRPL (Teacher AMS, MGP, Room VES, Group P)
#   - 13:00-13:50 → Course ENG II (Teacher RMS, 11IF1, Room ACB, Group P)
#   - 13:00-13:50 → Course ENG II (Teacher RMS, 11IF2, Room ACB, Group P)
#   - 13:00-13:50 → Course MADAS II (Teacher ASH, 11TE1, Room AMP, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher ASH, 11TE2, Room AMP, Group T)
#   - 13:00-13:50 → Course SISTAN (Teacher FST, IPM, Room MPR, Group P)
#   - 13:00-13:50 → Course SISTAN (Teacher FST, IPM, Room MPR, Group P)
#   - 13:00-13:50 → Course PA II (Teacher ADS, OPH, Room ADS, Group P)
#   - 13:00-13:50 → Course PA II (Teacher ADS, OPH, Room ADS, Group P)
#   - 13:00-13:50 → Course ELKA I (Teacher DPL, ARH, Room IFY, Group T)
#   - 13:00-13:50 → Course ALSTRU (Teacher YUL, 12TB, Room RFK, Group P)
#   - 13:00-13:50 → Course PSI (Teacher SGS, 13SI1, Room SGS, Group P)
#   - 13:00-13:50 → Course PSI (Teacher SGS, 13SI2, Room SGS, Group P)
#   - 13:00-13:50 → Course LABTEK (Teacher TML, 13TB, Room NJT, Group T)
#   - 13:00-13:50 → Course TA II (Teacher RDS, 14IF2, Room RDS, Group P)
#   - 13:00-13:50 → Course ENTER (Teacher IHT, 14TE2, Room WMS, Group T)
#   - 13:00-13:50 → Course PBD (Teacher VES, AMS, Room HTO, Group P)
#   - 13:00-13:50 → Course ADL (Teacher BSS, 14IF1, Room RMM, Group T)
#   - 13:00-13:50 → Course PKPL (Teacher RCH, RAS, Room ISW, Group P)
#   - 14:00-14:50 → Course PNKI (Teacher TLG, 32TI2, Room JBJ, Group P)
#   - 14:00-14:50 → Course PBDSI (Teacher SGS, SEP, Room IPM, Group T)
#   - 14:00-14:50 → Course PSL 2 (Teacher SHT, 12MR1, Room WMS, Group T)
#   - 14:00-14:50 → Course TA I (Teacher AMS, 44TRPL3, Room JYD, Group P)
#   - 14:00-14:50 → Course ERP (Teacher PAT, SRT, Room -, Group T)
#   - 14:00-14:50 → Course PEMPROS (Teacher CHP, GFP, Room ANA, Group T)
#   - 14:00-14:50 → Course KIMOR (Teacher RFK, BSS, Room AMS, Group T)
#   - 14:00-14:50 → Course ENTER (Teacher IHT, 14TE1, Room JHS, Group P)
#   - 14:00-14:50 → Course PPL (Teacher HER, 31TI1, Room MMK, Group P)
#   - 14:00-14:50 → Course LOGEO (Teacher NSS, 14MR1, Room IFY, Group T)
#   - 14:00-14:50 → Course PM (Teacher ASD, RSL, Room TAP, Group T)
#   - 14:00-14:50 → Course ALSTRUDAT (Teacher GHP, 31TI1, Room GHP, Group P)
#   - 14:00-14:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room GHP, Group P)
#   - 14:00-14:50 → Course PRPL (Teacher AMS, MGP, Room VES, Group P)
#   - 14:00-14:50 → Course MADAS II (Teacher ASH, 11TE2, Room AMP, Group T)
#   - 14:00-14:50 → Course TEK.NET (Teacher TAP, 32TI1, Room TLG, Group P)
#   - 14:00-14:50 → Course SISTAN (Teacher FST, IPM, Room MPR, Group P)
#   - 14:00-14:50 → Course SISTAN (Teacher FST, IPM, Room MPR, Group P)
#   - 14:00-14:50 → Course PA II (Teacher ADS, OPH, Room ADS, Group P)
#   - 14:00-14:50 → Course PA II (Teacher ADS, OPH, Room ADS, Group P)
#   - 14:00-14:50 → Course SINSIS (Teacher GFP, ARH, Room HTO, Group T)
#   - 14:00-14:50 → Course SINSIS (Teacher GFP, ARH, Room HTO, Group T)
#   - 14:00-14:50 → Course ALSTRU (Teacher YUL, 12TB, Room RFK, Group P)
#   - 14:00-14:50 → Course PSI (Teacher SGS, 13SI1, Room SGS, Group P)
#   - 14:00-14:50 → Course LABTEK (Teacher TML, 13TB, Room NJT, Group T)
#   - 14:00-14:50 → Course TA II (Teacher RDS, 14IF2, Room RDS, Group P)
#   - 14:00-14:50 → Course LOGIN (Teacher ASD, RDS, Room ASD, Group P)
#   - 14:00-14:50 → Course EPROF (Teacher 14IF2, GD923, Room HTS, Group P)
#   - 14:00-14:50 → Course TEK.NET (Teacher TAP, MEP, Room MMM, Group P)
#   - 15:00-15:50 → Course DP (Teacher GFP, HTO, Room RDP, Group T)
#   - 15:00-15:50 → Course FISDAS IIA (Teacher AFS, 11TE2, Room OPH, Group T)
#   - 15:00-15:50 → Course KP (Teacher GIW, FST, Room AFS, Group P)
#   - 15:00-15:50 → Course TEKNO (Teacher WMS, 14IF1, Room TLG, Group T)
#   - 15:00-15:50 → Course SISOP (Teacher IPM, GIW, Room MMK, Group P)
#   - 15:00-15:50 → Course PSI (Teacher SGS, 13SI1, Room JHS, Group T)
#   - 15:00-15:50 → Course PBD (Teacher HER, RAS, Room YUL, Group P)
#   - 15:00-15:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room IPM, Group P)
#   - 15:00-15:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room IPM, Group P)
#   - 15:00-15:50 → Course FISDAS IIB (Teacher NMA, 11IF1, Room NMA, Group T)
#   - 15:00-15:50 → Course FISDAS IIA (Teacher GDE, 11TB, Room GDE, Group P)
#   - 15:00-15:50 → Course PBO (Teacher ADS, AYS, Room ADS, Group P)
#   - 15:00-15:50 → Course PBO (Teacher CHP, AMS, Room HTO, Group P)
#   - 15:00-15:50 → Course SISOP (Teacher HTO, CHP, Room IFY, Group T)
#   - 15:00-15:50 → Course SISOP (Teacher HTO, CHP, Room IFY, Group T)
#   - 15:00-15:50 → Course LABTEK (Teacher TML, 13TB, Room JYD, Group P)
#   - 15:00-15:50 → Course TEKNO (Teacher WMS, 14IF2, Room BSS, Group T)
#   - 15:00-15:50 → Course TA I/II (Teacher AFS, 14TE2, Room ASD, Group T)
#   - 15:00-15:50 → Course KESIS (Teacher SRT, JHS, Room ARH, Group T)
#   - 15:00-15:50 → Course SISOP (Teacher HTO, CHP, Room RCH, Group T)
#   - 15:00-15:50 → Course ING IV (Teacher MPR, 42TRPL2, Room ISW, Group P)
#   - 16:00-16:50 → Course KEPAL (Teacher JHS, 13IF1, Room ASH, Group P)
#   - 16:00-16:50 → Course SINSIS (Teacher GFP, ARH, Room YAG, Group T)
#   - 16:00-16:50 → Course PROG  II (Teacher GPS, 12TE1, Room HER, Group T)
#   - 16:00-16:50 → Course JARKOM (Teacher DPL, ABS, Room AMP, Group T)
#   - 16:00-16:50 → Course ENTER (Teacher IHT, 14TE1, Room MMM, Group P)
#   - 16:00-16:50 → Course FISDAS IIB (Teacher NMA, ISW, Room SGS, Group T)
#   - 16:00-16:50 → Course PEMPRO (Teacher JBJ, 12MR1, Room VES, Group T)
#   - 16:00-16:50 → Course KEPAL (Teacher JHS, 13IF2, Room MMS, Group P)
#   - 16:00-16:50 → Course DETING (Teacher RIS, THL, Room FBA, Group T)
#   - 16:00-16:50 → Course FISDAS IIB (Teacher NMA, 11IF2, Room RSL, Group T)
#   - 16:00-16:50 → Course PBD (Teacher HER, RAS, Room FST, Group P)
#   - 16:00-16:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room IPM, Group P)
#   - 16:00-16:50 → Course PBO (Teacher ADS, AYS, Room ADS, Group P)
#   - 16:00-16:50 → Course PBO (Teacher ADS, AYS, Room ADS, Group P)
#   - 16:00-16:50 → Course LOGIN (Teacher ASD, RDS, Room ACB, Group P)
#   - 16:00-16:50 → Course SISOP (Teacher HTO, CHP, Room IFY, Group T)
#   - 16:00-16:50 → Course SISOP (Teacher HTO, CHP, Room IFY, Group T)
#   - 16:00-16:50 → Course SPT (Teacher JHS, 13IF1, Room IUS, Group T)
#   - 16:00-16:50 → Course LABTEK (Teacher TML, 13TB, Room JYD, Group P)
#   - 16:00-16:50 → Course TA I/II (Teacher AFS, 14TE1, Room BSS, Group T)
#   - 16:00-16:50 → Course MANPRO (Teacher NSS, 14TB, Room MMK, Group T)
#
# Rabu:
#   - 08:00-08:50 → Course JARKOM II (Teacher ABS, 13TE1, Room ASH, Group T)
#   - 08:00-08:50 → Course TA I/II (Teacher PAT, 14SI1, Room YUL, Group T)
#   - 08:00-08:50 → Course ALSTRUDAT (Teacher GHP, 31TI1, Room FST, Group P)
#   - 08:00-08:50 → Course PKPL (Teacher RCH, 32TI2, Room GPS, Group P)
#   - 08:00-08:50 → Course TA II (Teacher RFK, JYD, Room ABS, Group T)
#   - 08:00-08:50 → Course ALJALI (Teacher JUN, 12SI1, Room VES, Group T)
#   - 08:00-08:50 → Course KUPEL (Teacher AMS, 44TRPL3, Room HER, Group P)
#   - 08:00-08:50 → Course ENG III (Teacher MPR, 13IF2, Room JUN, Group T)
#   - 08:00-08:50 → Course PASTI (Teacher RCH, OPH, Room MMM, Group P)
#   - 08:00-08:50 → Course TA II (Teacher ADS, 44TRPL1, Room HSS, Group P)
#   - 08:00-08:50 → Course KP (Teacher GIW, FST, Room IHT, Group T)
#   - 08:00-08:50 → Course PBO (Teacher CHP, AMS, Room RSL, Group P)
#   - 08:00-08:50 → Course PPL (Teacher HER, THL, Room GHP, Group P)
#   - 08:00-08:50 → Course PRPL (Teacher AMS, MGP, Room MPR, Group P)
#   - 08:00-08:50 → Course FISDAS IIB (Teacher GDE, ISW, Room SHT, Group T)
#   - 08:00-08:50 → Course MADAS II (Teacher REG, 11TM, Room ISW, Group T)
#   - 08:00-08:50 → Course PASTI (Teacher RCH, MAL, Room TAP, Group P)
#   - 08:00-08:50 → Course PASTI (Teacher RCH, MAL, Room TAP, Group P)
#   - 08:00-08:50 → Course PA II (Teacher FST, 32TK1, Room TLG, Group P)
#   - 08:00-08:50 → Course PA II (Teacher FST, 32TK2, Room TLG, Group P)
#   - 08:00-08:50 → Course SISOP (Teacher HTO, CHP, Room PAT, Group T)
#   - 08:00-08:50 → Course NRG (Teacher ISW, 12MR1, Room REG, Group T)
#   - 08:00-08:50 → Course NRG (Teacher ISW, 12MR2, Room REG, Group T)
#   - 08:00-08:50 → Course PM (Teacher ASD, RSL, Room ACB, Group P)
#   - 08:00-08:50 → Course PM (Teacher ASD, RSL, Room ACB, Group P)
#   - 08:00-08:50 → Course DWBI (Teacher SGS, SEP, Room SRT, Group T)
#   - 08:00-08:50 → Course PIP (Teacher FBA, 13TB, Room MMK, Group T)
#   - 08:00-08:50 → Course PNKI (Teacher TLG, 32TK1, Room IPM, Group P)
#   - 08:00-08:50 → Course DASPRO (Teacher OPH, MGP, Room RCH, Group P)
#   - 08:00-08:50 → Course MADAS II (Teacher YAG, ARS, Room APT, Group T)
#   - 09:00-09:50 → Course FISDAS IIA (Teacher GDE, 11TB, Room FBA, Group T)
#   - 09:00-09:50 → Course ING IV (Teacher MPR, 32TK1, Room RDS, Group T)
#   - 09:00-09:50 → Course TA I/II (Teacher PAT, 14SI2, Room WMS, Group T)
#   - 09:00-09:50 → Course FISDAS IIA (Teacher AFS, 11TE1, Room RMS, Group T)
#   - 09:00-09:50 → Course PEMPROS (Teacher CHP, GFP, Room ASD, Group T)
#   - 09:00-09:50 → Course CERTAN (Teacher GPS, DPL, Room AGA, Group T)
#   - 09:00-09:50 → Course KEPAL (Teacher JHS, 13IF1, Room ARH, Group P)
#   - 09:00-09:50 → Course KP (Teacher GIW, FST, Room NMA, Group T)
#   - 09:00-09:50 → Course ALJALI (Teacher JUN, 12IF1, Room HER, Group T)
#   - 09:00-09:50 → Course PPL (Teacher HER, 31TI1, Room GHP, Group P)
#   - 09:00-09:50 → Course PPL (Teacher HER, THL, Room GHP, Group P)
#   - 09:00-09:50 → Course PBD (Teacher HER, 31TK1, Room MMS, Group P)
#   - 09:00-09:50 → Course PBD (Teacher VES, AMS, Room RMM, Group P)
#   - 09:00-09:50 → Course PRPL (Teacher AMS, MGP, Room MPR, Group P)
#   - 09:00-09:50 → Course RPL (Teacher ACB, 11IF1, Room ISW, Group T)
#   - 09:00-09:50 → Course RPL (Teacher ACB, 11IF2, Room ISW, Group T)
#   - 09:00-09:50 → Course FISDAS IIB (Teacher GDE, ISW, Room SHT, Group T)
#   - 09:00-09:50 → Course PASTI (Teacher RCH, MAL, Room TAP, Group P)
#   - 09:00-09:50 → Course PA II (Teacher FST, 32TK1, Room TLG, Group P)
#   - 09:00-09:50 → Course PA II (Teacher FST, 32TK2, Room TLG, Group P)
#   - 09:00-09:50 → Course SISOP (Teacher HTO, CHP, Room PAT, Group T)
#   - 09:00-09:50 → Course SISOP (Teacher HTO, CHP, Room PAT, Group T)
#   - 09:00-09:50 → Course EPROF (Teacher SML, GIW, Room GIW, Group P)
#   - 09:00-09:50 → Course EPROF (Teacher SML, GIW, Room GIW, Group P)
#   - 09:00-09:50 → Course PM (Teacher ASD, RSL, Room ACB, Group P)
#   - 09:00-09:50 → Course DWBI (Teacher SGS, SEP, Room SRT, Group T)
#   - 09:00-09:50 → Course DWBI (Teacher SGS, SEP, Room SRT, Group T)
#   - 09:00-09:50 → Course AKBI (Teacher WMS, 13MR1, Room NSS, Group T)
#   - 09:00-09:50 → Course AKBI (Teacher WMS, 13MR2, Room NSS, Group T)
#   - 09:00-09:50 → Course PIP (Teacher FBA, 13TB, Room MMK, Group T)
#   - 09:00-09:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room RIS, Group P)
#   - 10:00-10:50 → Course KIMDAS B (Teacher AGA, SFA, Room FBA, Group T)
#   - 10:00-10:50 → Course PBDSI (Teacher SGS, SEP, Room AFS, Group T)
#   - 10:00-10:50 → Course TA II (Teacher RDS, 14IF2, Room MMS, Group P)
#   - 10:00-10:50 → Course ALJALI (Teacher JUN, 12SI2, Room -, Group T)
#   - 10:00-10:50 → Course TA I (Teacher RDS, 14IF1, Room HTO, Group T)
#   - 10:00-10:50 → Course PSL 2 (Teacher SHT, 12MR2, Room ARH, Group T)
#   - 10:00-10:50 → Course FISDAS IIA (Teacher AFS, 11TE1, Room SRT, Group T)
#   - 10:00-10:50 → Course ALJALI (Teacher SML, IFY, Room IUS, Group T)
#   - 10:00-10:50 → Course FISDAS IIA (Teacher AFS, 11TE2, Room NJT, Group T)
#   - 10:00-10:50 → Course TEKNO (Teacher RIS, 44TRPL2, Room AGA, Group P)
#   - 10:00-10:50 → Course ERP (Teacher PAT, SRT, Room ANA, Group T)
#   - 10:00-10:50 → Course PEMPROS (Teacher CHP, GFP, Room FST, Group T)
#   - 10:00-10:50 → Course TA I/II (Teacher AFS, 14TE1, Room BSS, Group T)
#   - 10:00-10:50 → Course ING II (Teacher RMM, 31TK1, Room HER, Group P)
#   - 10:00-10:50 → Course ING II (Teacher RMM, 31TK2, Room HER, Group P)
#   - 10:00-10:50 → Course PSW II (Teacher OPH, AAP, Room TLG, Group P)
#   - 10:00-10:50 → Course PSW II (Teacher OPH, AAP, Room TLG, Group P)
#   - 10:00-10:50 → Course PSW II (Teacher ADS, AAP, Room OPH, Group P)
#   - 10:00-10:50 → Course FISDAS IIA (Teacher AFS, 11TE2, Room GFP, Group T)
#   - 10:00-10:50 → Course PLSJ (Teacher MMS, EDS, Room GIW, Group P)
#   - 10:00-10:50 → Course PLSJ (Teacher MMS, EDS, Room GIW, Group P)
#   - 10:00-10:50 → Course PROBSTAT (Teacher AMP, 42TRPL1, Room AMP, Group P)
#   - 10:00-10:50 → Course PROBSTAT (Teacher AMP, 42TRPL2, Room AMP, Group P)
#   - 10:00-10:50 → Course JARKOM (Teacher DPL, ABS, Room DPL, Group T)
#   - 10:00-10:50 → Course ATI (Teacher 33TI1, AUD, Room WMS, Group P)
#   - 10:00-10:50 → Course ATI (Teacher 33TI2, AUD, Room JYD, Group P)
#   - 10:00-10:50 → Course ATI (Teacher 33TK1, AUD, Room IPM, Group P)
#   - 10:00-10:50 → Course PAM (Teacher HTO, RDS, Room JHS, Group T)
#   - 10:00-10:50 → Course SM/SP (Teacher RIS, OPH, Room AMS, Group P)
#   - 10:00-10:50 → Course EPROF (Teacher MMM, 14TB, Room NSS, Group T)
#   - 10:00-10:50 → Course SISOP (Teacher HTO, CHP, Room GHP, Group P)
#   - 10:00-10:50 → Course MANPRO (Teacher NSS, 13MR1, Room ASD, Group T)
#   - 10:00-10:50 → Course TRB (Teacher MMK, 13TB, Room VES, Group T)
#   - 11:00-11:50 → Course KEPAL (Teacher JHS, 13IF2, Room HSS, Group P)
#   - 11:00-11:50 → Course TA I/II (Teacher PAT, 14SI2, Room PAT, Group T)
#   - 11:00-11:50 → Course DP (Teacher GFP, HTO, Room IHT, Group T)
#   - 11:00-11:50 → Course PAM (Teacher ADS, TAP, Room RIS, Group T)
#   - 11:00-11:50 → Course ADL (Teacher BSS, 13SI1, Room HTS, Group P)
#   - 11:00-11:50 → Course SISOP (Teacher IPM, GIW, Room NMA, Group P)
#   - 11:00-11:50 → Course LOGIN (Teacher ASD, RDS, Room YAG, Group P)
#   - 11:00-11:50 → Course PBO (Teacher CHP, AMS, Room RCH, Group P)
#   - 11:00-11:50 → Course DWBI (Teacher SGS, SEP, Room NJT, Group T)
#   - 11:00-11:50 → Course ING II (Teacher RMM, 31TK1, Room HER, Group P)
#   - 11:00-11:50 → Course PSW II (Teacher OPH, AAP, Room TLG, Group P)
#   - 11:00-11:50 → Course PSW II (Teacher OPH, AAP, Room TLG, Group P)
#   - 11:00-11:50 → Course PSW II (Teacher OPH, AAP, Room OPH, Group P)
#   - 11:00-11:50 → Course FISDAS IIA (Teacher AFS, 11TE1, Room GFP, Group T)
#   - 11:00-11:50 → Course FISDAS IIA (Teacher AFS, 11TE2, Room GFP, Group T)
#   - 11:00-11:50 → Course FISDAS IIB (Teacher NMA, ISW, Room AGA, Group T)
#   - 11:00-11:50 → Course PLSJ (Teacher MMS, EDS, Room GIW, Group P)
#   - 11:00-11:50 → Course PROBSTAT (Teacher AMP, 42TRPL2, Room AMP, Group P)
#   - 11:00-11:50 → Course JARKOM (Teacher DPL, ABS, Room DPL, Group T)
#   - 11:00-11:50 → Course JARKOM (Teacher DPL, ABS, Room DPL, Group T)
#   - 11:00-11:50 → Course ATI (Teacher 33TI2, AUD, Room JYD, Group P)
#   - 11:00-11:50 → Course PAM (Teacher HTO, RDS, Room JHS, Group T)
#   - 11:00-11:50 → Course PAM (Teacher HTO, RDS, Room JHS, Group T)
#   - 11:00-11:50 → Course SM/SP (Teacher RIS, OPH, Room AMS, Group P)
#   - 11:00-11:50 → Course SM/SP (Teacher RIS, OPH, Room AMS, Group P)
#   - 11:00-11:50 → Course AKPL (Teacher VES, MEP, Room REG, Group P)
#   - 11:00-11:50 → Course ADS (Teacher PAT, ACB, Room FBA, Group T)
#   - 13:00-13:50 → Course PNKI (Teacher TLG, 41TRPL2, Room DPL, Group T)
#   - 13:00-13:50 → Course EPROF (Teacher ANA, 14MR2, Room RMM, Group T)
#   - 13:00-13:50 → Course FISDAS IIA (Teacher GDE, 11TB, Room FBA, Group T)
#   - 13:00-13:50 → Course PSL 2 (Teacher SHT, 12MR1, Room GFP, Group T)
#   - 13:00-13:50 → Course LABTEK (Teacher TML, 13TB, Room MMK, Group P)
#   - 13:00-13:50 → Course PKPL (Teacher RCH, 32TI1, Room GPS, Group P)
#   - 13:00-13:50 → Course ING II (Teacher RMM, 31TI2, Room JBJ, Group P)
#   - 13:00-13:50 → Course LABTEK (Teacher TML, 13TB, Room SML, Group P)
#   - 13:00-13:50 → Course PEMPRO (Teacher JBJ, 12MR2, Room HER, Group T)
#   - 13:00-13:50 → Course PSI (Teacher SGS, 13SI2, Room SRT, Group T)
#   - 13:00-13:50 → Course MATDIS (Teacher AMP, 11SI1, Room AFS, Group T)
#   - 13:00-13:50 → Course FISDAS IIB (Teacher GDE, ISW, Room SHT, Group T)
#   - 13:00-13:50 → Course OFP I (Teacher NJT, TML, Room IUS, Group T)
#   - 13:00-13:50 → Course EPROF (Teacher 14IF2, GD923, Room REG, Group P)
#   - 13:00-13:50 → Course PLSJ (Teacher MMS, EDS, Room BSS, Group P)
#   - 13:00-13:50 → Course PSW II (Teacher GHP, TAP, Room GHP, Group P)
#   - 13:00-13:50 → Course MADAS II (Teacher ASH, ARS, Room IHT, Group P)
#   - 13:00-13:50 → Course FISDAS IIA (Teacher GDE, 11TB, Room RFK, Group T)
#   - 13:00-13:50 → Course PNKI (Teacher TLG, TLG, Room RCH, Group P)
#   - 13:00-13:50 → Course PNKI (Teacher TLG, TLG, Room RCH, Group P)
#   - 13:00-13:50 → Course ING IV (Teacher MPR, 32TK1, Room FST, Group P)
#   - 13:00-13:50 → Course ING IV (Teacher MPR, 32TK2, Room FST, Group P)
#   - 13:00-13:50 → Course PA II (Teacher ADS, OPH, Room MPR, Group P)
#   - 13:00-13:50 → Course PA II (Teacher ADS, OPH, Room MPR, Group P)
#   - 13:00-13:50 → Course PRAK GEN BIMOL (Teacher RFK, 12TB, Room APT, Group P)
#   - 13:00-13:50 → Course DWBI (Teacher SGS, SEP, Room SGS, Group P)
#   - 13:00-13:50 → Course DWBI (Teacher SGS, SEP, Room SGS, Group P)
#   - 13:00-13:50 → Course TEKEU (Teacher WMS, 14MR1, Room NSS, Group T)
#   - 13:00-13:50 → Course TEKEU (Teacher WMS, 14MR2, Room NSS, Group T)
#   - 13:00-13:50 → Course REMU (Teacher HSS, 13MR2, Room IPM, Group P)
#   - 14:00-14:50 → Course KIMDAS B (Teacher AGA, SFA, Room TLG, Group T)
#   - 14:00-14:50 → Course PAM (Teacher HTO, RDS, Room CHP, Group T)
#   - 14:00-14:50 → Course ALJALI (Teacher SML, IFY, Room SRT, Group T)
#   - 14:00-14:50 → Course MADAS II (Teacher ASH, ARS, Room SFA, Group T)
#   - 14:00-14:50 → Course GEN BIMOL (Teacher MMM, 12TB, Room JYD, Group T)
#   - 14:00-14:50 → Course PBO (Teacher CHP, AMS, Room ARH, Group P)
#   - 14:00-14:50 → Course PBO (Teacher CHP, AMS, Room MMM, Group P)
#   - 14:00-14:50 → Course PSW II (Teacher GHP, TAP, Room GHP, Group P)
#   - 14:00-14:50 → Course PSW II (Teacher GHP, TAP, Room GHP, Group P)
#   - 14:00-14:50 → Course SISOP (Teacher GIW, IRS, Room AMS, Group P)
#   - 14:00-14:50 → Course MADAS II (Teacher ASH, ARS, Room IHT, Group P)
#   - 14:00-14:50 → Course MATDIS (Teacher AMP, YAG, Room GFP, Group P)
#   - 14:00-14:50 → Course MATDIS (Teacher AMP, YAG, Room GFP, Group P)
#   - 14:00-14:50 → Course PNKI (Teacher TLG, TLG, Room RCH, Group P)
#   - 14:00-14:50 → Course ING IV (Teacher MPR, 32TK1, Room FST, Group P)
#   - 14:00-14:50 → Course PA II (Teacher ADS, OPH, Room MPR, Group P)
#   - 14:00-14:50 → Course SISOP (Teacher HTO, CHP, Room RIS, Group T)
#   - 14:00-14:50 → Course SISOP (Teacher HTO, CHP, Room RIS, Group T)
#   - 14:00-14:50 → Course PRAK GEN BIMOL (Teacher RFK, 12TB, Room APT, Group P)
#   - 14:00-14:50 → Course DWBI (Teacher SGS, SEP, Room SGS, Group P)
#   - 14:00-14:50 → Course SISOP (Teacher IPM, GIW, Room GIW, Group P)
#   - 14:00-14:50 → Course PBD (Teacher HER, RAS, Room NJT, Group P)
#   - 14:00-14:50 → Course DASPRO (Teacher OPH, MGP, Room AFS, Group P)
#   - 15:00-15:50 → Course ING VI (Teacher RMM, 43TRPL2, Room AMS, Group P)
#   - 15:00-15:50 → Course LABTEK (Teacher TML, 13TB, Room SFA, Group P)
#   - 15:00-15:50 → Course ING II (Teacher RMM, 41TRPL2, Room HSS, Group P)
#   - 15:00-15:50 → Course PA III (Teacher RIS, 43TRPL2, Room JHS, Group T)
#   - 15:00-15:50 → Course PSW II (Teacher OPH, AAP, Room ASH, Group P)
#   - 15:00-15:50 → Course PSW II (Teacher GHP, TAP, Room MMM, Group P)
#   - 15:00-15:50 → Course SISTAN (Teacher FST, IPM, Room GHP, Group P)
#   - 15:00-15:50 → Course PASTI (Teacher RCH, OPH, Room ANA, Group P)
#   - 15:00-15:50 → Course ERP (Teacher PAT, SRT, Room FIS, Group T)
#   - 15:00-15:50 → Course UI/UX (Teacher IUS, SEP, Room AGA, Group P)
#   - 15:00-15:50 → Course TEKNO (Teacher WMS, 14TB, Room RIS, Group T)
#   - 15:00-15:50 → Course PAM (Teacher HTO, RDS, Room -, Group T)
#   - 15:00-15:50 → Course PROBSTAT (Teacher AMP, 42TRPL1, Room GFP, Group P)
#   - 15:00-15:50 → Course SISOP (Teacher IPM, GIW, Room IFY, Group P)
#   - 15:00-15:50 → Course ALSTRUDAT (Teacher ACB, IUS, Room ACB, Group T)
# ...
#   - 11:00-11:50 → Course PNKI (Teacher TLG, TLG, Room VES, Group P)
#   - 11:00-11:50 → Course PROG I (Teacher GFP, 11TE1, Room AMP, Group T)
#   - 11:00-11:50 → Course FISDAS IIB (Teacher GDE, ISW, Room REG, Group T)
#   - 11:00-11:50 → Course FISDAS IIB (Teacher GDE, ISW, Room REG, Group T)
#   - 11:00-11:50 → Course ANJAR (Teacher GIW, PDS, Room FST, Group P)
#   - 11:00-11:50 → Course ANJAR (Teacher GIW, PDS, Room FST, Group P)
#   - 11:00-11:50 → Course PROBSTAT (Teacher AMP, 42TRPL1, Room ADS, Group P)
#   - 11:00-11:50 → Course PROBSTAT (Teacher AMP, 42TRPL2, Room ADS, Group P)
#   - 11:00-11:50 → Course JARKOM (Teacher DPL, ABS, Room CHP, Group T)
#   - 11:00-11:50 → Course JARKOM (Teacher DPL, ABS, Room CHP, Group T)
#   - 11:00-11:50 → Course STAINFER (Teacher FIS, REG, Room SFA, Group T)
#   - 11:00-11:50 → Course STAINFER (Teacher FIS, REG, Room SFA, Group T)
#   - 11:00-11:50 → Course TA II (Teacher IPM, 33TK1, Room GIW, Group P)
#   - 11:00-11:50 → Course TA II (Teacher IPM, 33TK2, Room GIW, Group P)
#   - 11:00-11:50 → Course SPT (Teacher JHS, 13IF1, Room HTO, Group T)
#   - 11:00-11:50 → Course SPT (Teacher JHS, 13IF2, Room HTO, Group T)
#   - 11:00-11:50 → Course AKBI (Teacher WMS, 13MR1, Room NSS, Group T)
#   - 11:00-11:50 → Course AKBI (Teacher WMS, 13MR2, Room NSS, Group T)
#   - 11:00-11:50 → Course BUSNOV (Teacher NSS, 14MR1, Room ISW, Group P)
#   - 11:00-11:50 → Course BUSNOV (Teacher NSS, 14MR2, Room ISW, Group P)
#   - 13:00-13:50 → Course PA I (Teacher SML, 31TK1, Room NMA, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher YAG, ARS, Room YUL, Group T)
#   - 13:00-13:50 → Course ENG III (Teacher MPR, 13IF2, Room FST, Group T)
#   - 13:00-13:50 → Course ADL (Teacher BSS, 13SI1, Room BSS, Group P)
#   - 13:00-13:50 → Course ENG II (Teacher RMS, 11TM, Room JBJ, Group T)
#   - 13:00-13:50 → Course PBO (Teacher CHP, AMS, Room RDS, Group P)
#   - 13:00-13:50 → Course TA I/II (Teacher AFS, 14TE2, Room TML, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher REG, 11TM, Room SRT, Group T)
#   - 13:00-13:50 → Course EPROF (Teacher 14IF1, GD923, Room JUN, Group P)
#   - 13:00-13:50 → Course PP (Teacher NJT, MMK, Room ARH, Group P)
#   - 13:00-13:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room SML, Group P)
#   - 13:00-13:50 → Course PKPL (Teacher RCH, RAS, Room RCH, Group P)
#   - 13:00-13:50 → Course PKPL (Teacher RCH, RAS, Room RCH, Group P)
#   - 13:00-13:50 → Course PA II (Teacher FST, 32TK1, Room -, Group P)
#   - 13:00-13:50 → Course PEMPRO (Teacher JBJ, 12MR1, Room REG, Group T)
#   - 13:00-13:50 → Course PRAK ALSTRU (Teacher APT, 12TB, Room MMK, Group T)
#   - 13:00-13:50 → Course PSI (Teacher SGS, 13SI1, Room SGS, Group T)
#   - 13:00-13:50 → Course PSI (Teacher SGS, 13SI2, Room SGS, Group T)
#   - 13:00-13:50 → Course LOGEO (Teacher NSS, 14MR1, Room ISW, Group P)
#   - 14:00-14:50 → Course KIMDAS B (Teacher AGA, SFA, Room DPL, Group T)
#   - 14:00-14:50 → Course KEPAL (Teacher JHS, 13IF2, Room GHP, Group P)
#   - 14:00-14:50 → Course TA I (Teacher RDS, 14IF1, Room MMM, Group P)
#   - 14:00-14:50 → Course BUSNOV (Teacher NSS, 14MR2, Room ARH, Group T)
#   - 14:00-14:50 → Course PAM (Teacher ADS, TAP, Room SGS, Group T)
#   - 14:00-14:50 → Course KP (Teacher GIW, FST, Room MPR, Group P)
#   - 14:00-14:50 → Course PASTI (Teacher RCH, OPH, Room YUL, Group P)
#   - 14:00-14:50 → Course SPT (Teacher JHS, 13IF2, Room ABS, Group T)
#   - 14:00-14:50 → Course RPL (Teacher ACB, 11IF1, Room CHP, Group T)
#   - 14:00-14:50 → Course MATDIS (Teacher AMP, 11SI1, Room IHT, Group T)
#   - 14:00-14:50 → Course PBD (Teacher HER, 31TK2, Room SHT, Group P)
#   - 14:00-14:50 → Course AKPL (Teacher VES, MEP, Room REG, Group P)
#   - 14:00-14:50 → Course SISOP (Teacher HTO, CHP, Room MMS, Group T)
#   - 14:00-14:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room SML, Group P)
#   - 14:00-14:50 → Course PRAK PROG I (Teacher GFP, FCS, Room AFS, Group P)
#   - 14:00-14:50 → Course PRAK PROG I (Teacher GFP, FCS, Room AFS, Group P)
#   - 14:00-14:50 → Course PKPL (Teacher RCH, RAS, Room RCH, Group P)
#   - 14:00-14:50 → Course PA II (Teacher FST, 32TK1, Room -, Group P)
#   - 14:00-14:50 → Course PRAK ALSTRU (Teacher APT, 12TB, Room MMK, Group T)
#   - 14:00-14:50 → Course ING VI (Teacher JYD, 33TK1, Room IPM, Group P)
#   - 14:00-14:50 → Course ING VI (Teacher JYD, 33TK2, Room IPM, Group P)
#   - 14:00-14:50 → Course PSI (Teacher SGS, 13SI1, Room SRT, Group T)
#   - 14:00-14:50 → Course PSI (Teacher SGS, 13SI2, Room SRT, Group T)
#   - 14:00-14:50 → Course ING VI (Teacher JYD, 33TK1, Room JHS, Group P)
#   - 15:00-15:50 → Course TA II (Teacher RDS, 14IF2, Room SML, Group T)
#   - 15:00-15:50 → Course SISOP (Teacher IPM, GIW, Room APT, Group P)
#   - 15:00-15:50 → Course ENTER (Teacher IHT, 14TE2, Room NJT, Group P)
#   - 15:00-15:50 → Course PM (Teacher ASD, RSL, Room JBJ, Group T)
#   - 15:00-15:50 → Course UI/UX (Teacher IUS, SEP, Room PAT, Group P)
#   - 15:00-15:50 → Course PSW II (Teacher GHP, TAP, Room AMP, Group P)
#   - 15:00-15:50 → Course PABI (Teacher MMS, MEP, Room HTS, Group P)
#   - 15:00-15:50 → Course PA II (Teacher FST, 32TK2, Room SGS, Group P)
#   - 15:00-15:50 → Course ING IV (Teacher MPR, 42TRPL1, Room GIW, Group P)
#   - 15:00-15:50 → Course ING IV (Teacher MPR, 42TRPL2, Room AMS, Group P)
#   - 15:00-15:50 → Course IMK (Teacher RIS, RDS, Room RCH, Group T)
#   - 15:00-15:50 → Course PA 1 (Teacher IFY, 31TI1, Room HER, Group P)
#   - 15:00-15:50 → Course PRAK PROG I (Teacher GFP, FCS, Room AFS, Group P)
#   - 15:00-15:50 → Course PRAK PROG I (Teacher GFP, FCS, Room AFS, Group P)
#   - 15:00-15:50 → Course ALSTRUDAT (Teacher ACB, IUS, Room DPL, Group T)
#   - 15:00-15:50 → Course ALSTRUDAT (Teacher ACB, IUS, Room DPL, Group T)
#   - 15:00-15:50 → Course ADS (Teacher PAT, ACB, Room RIS, Group T)
#   - 15:00-15:50 → Course ADS (Teacher PAT, ACB, Room RIS, Group T)
#   - 15:00-15:50 → Course KP (Teacher MPR, IFY, Room MPR, Group P)
#   - 15:00-15:50 → Course KP (Teacher MPR, IFY, Room MPR, Group P)
#   - 15:00-15:50 → Course ING VI (Teacher JYD, 33TK2, Room IPM, Group P)
#   - 15:00-15:50 → Course PA III (Teacher RIS, 43TRPL1, Room RMM, Group P)
#   - 15:00-15:50 → Course PA III (Teacher RIS, 43TRPL2, Room RMM, Group P)
#   - 15:00-15:50 → Course TEKENZ (Teacher RFK, BSS, Room FBA, Group P)
#   - 15:00-15:50 → Course UI/UX (Teacher IUS, SEP, Room RDS, Group P)
#   - 15:00-15:50 → Course UI/UX (Teacher IUS, SEP, Room RDS, Group P)
#   - 15:00-15:50 → Course PPP (Teacher SHT, FRED, Room ISW, Group P)
#   - 15:00-15:50 → Course PPP (Teacher SHT, FRED, Room ISW, Group P)
#   - 16:00-16:50 → Course PNKI (Teacher TLG, 41TRPL1, Room SML, Group T)
#   - 16:00-16:50 → Course JARKOM II (Teacher ABS, 13TE1, Room GDE, Group T)
#   - 16:00-16:50 → Course ING II (Teacher MPR, 41TRPL3, Room ABS, Group T)
#   - 16:00-16:50 → Course ALJALI (Teacher SML, IFY, Room TLG, Group T)
#   - 16:00-16:50 → Course TA I/II (Teacher PAT, 14SI2, Room AFS, Group T)
#   - 16:00-16:50 → Course ENTER (Teacher IHT, 14TE2, Room HSS, Group P)
#   - 16:00-16:50 → Course PSI (Teacher SGS, 13SI2, Room JBJ, Group T)
#   - 16:00-16:50 → Course EPROF (Teacher SML, GIW, Room MMM, Group P)
#   - 16:00-16:50 → Course ALJALI (Teacher IFY, SML, Room JHS, Group P)
#   - 16:00-16:50 → Course PA 1 (Teacher IFY, 31TI1, Room HER, Group P)
#   - 16:00-16:50 → Course PA 1 (Teacher IFY, 31TI2, Room HER, Group P)
#   - 16:00-16:50 → Course ALJALI (Teacher IFY, SML, Room TAP, Group P)
#   - 16:00-16:50 → Course SISTER (Teacher ESS, SFN, Room ESS, Group P)
#   - 16:00-16:50 → Course ADS (Teacher PAT, ACB, Room DPL, Group T)
#   - 16:00-16:50 → Course KP (Teacher MPR, IFY, Room MPR, Group P)
#   - 16:00-16:50 → Course KP (Teacher MPR, IFY, Room MPR, Group P)
#   - 16:00-16:50 → Course PA III (Teacher RIS, 43TRPL1, Room RMM, Group P)
#   - 16:00-16:50 → Course TEKENZ (Teacher RFK, BSS, Room FBA, Group P)
#   - 16:00-16:50 → Course TEKNO (Teacher RIS, MGP, Room RIS, Group P)
#   - 16:00-16:50 → Course PPP (Teacher SHT, FRED, Room ISW, Group P)
#   - 16:00-16:50 → Course PPP (Teacher SHT, FRED, Room ISW, Group P)
#
# Jumat:
#   - 08:00-08:50 → Course PSL 2 (Teacher SHT, 12MR1, Room JBJ, Group T)
#   - 08:00-08:50 → Course SISKEN (Teacher IHT, 13TE2, Room GDE, Group T)
#   - 08:00-08:50 → Course ALJALI (Teacher JUN, 12SI1, Room REG, Group T)
#   - 08:00-08:50 → Course PSL 2 (Teacher SHT, 12MR2, Room ARH, Group T)
#   - 08:00-08:50 → Course LABTEK (Teacher TML, 13TB, Room -, Group P)
#   - 08:00-08:50 → Course ALJALI (Teacher IFY, SML, Room FIS, Group T)
#   - 08:00-08:50 → Course TEKNO (Teacher WMS, 14IF2, Room DPL, Group T)
#   - 08:00-08:50 → Course PASTI (Teacher RCH, OPH, Room TLG, Group P)
#   - 08:00-08:50 → Course TA II (Teacher HER, 33TI1, Room RIS, Group T)
#   - 08:00-08:50 → Course ENTER (Teacher IHT, 14TE1, Room WMS, Group T)
#   - 08:00-08:50 → Course EPROF (Teacher 14IF1, GD923, Room RCH, Group P)
#   - 08:00-08:50 → Course ING II (Teacher RMM, 31TK2, Room RFK, Group P)
#   - 08:00-08:50 → Course ATI (Teacher 33TI1, AUD, Room MMK, Group P)
#   - 08:00-08:50 → Course ATI (Teacher 33TK2, AUD, Room MMS, Group P)
#   - 08:00-08:50 → Course ING IV (Teacher MPR, 32TK2, Room SRT, Group P)
#   - 08:00-08:50 → Course ALSTRUDAT (Teacher ACB, IUS, Room HTO, Group T)
#   - 08:00-08:50 → Course ALSTRUDAT (Teacher GHP, MAL, Room FST, Group P)
#   - 09:00-09:50 → Course PA I (Teacher SML, 31TK2, Room REG, Group T)
#   - 09:00-09:50 → Course PBO (Teacher ADS, 42TRPL2, Room RFK, Group P)
#   - 09:00-09:50 → Course ALJALI (Teacher JUN, 12SI2, Room TAP, Group T)
#   - 09:00-09:50 → Course PSL 2 (Teacher SHT, 12MR1, Room RMS, Group T)
#   - 09:00-09:50 → Course BUSNOV (Teacher NSS, 14MR2, Room AMP, Group T)
#   - 09:00-09:50 → Course TA II (Teacher RFK, JYD, Room JYD, Group T)
#   - 09:00-09:50 → Course SISMIK (Teacher ARH, 13TE2, Room RSL, Group T)
#   - 09:00-09:50 → Course ING VI (Teacher JYD, 33TK2, Room ANA, Group P)
#   - 09:00-09:50 → Course SOSPRO (Teacher TLG, TAP, Room SGS, Group T)
#   - 09:00-09:50 → Course SISOP (Teacher IPM, GIW, Room ABS, Group P)
#   - 09:00-09:50 → Course SISTER (Teacher ESS, 32TK2, Room NMA, Group P)
#   - 09:00-09:50 → Course ABD (Teacher GHP, RCH, Room FIS, Group T)
#   - 09:00-09:50 → Course PLSJ (Teacher MMS, 32TK2, Room JUN, Group P)
#   - 09:00-09:50 → Course TA I (Teacher RDS, 14IF1, Room NJT, Group P)
#   - 09:00-09:50 → Course ENG II (Teacher RMS, 11TE1, Room VES, Group T)
#   - 09:00-09:50 → Course NRG (Teacher ISW, 12MR1, Room HTO, Group T)
#   - 09:00-09:50 → Course SISOP (Teacher GIW, IRS, Room SRT, Group P)
#   - 09:00-09:50 → Course MATDIS (Teacher AMP, YAG, Room RDS, Group P)
#   - 09:00-09:50 → Course PA II (Teacher ADS, OPH, Room HER, Group P)
#   - 09:00-09:50 → Course ING II (Teacher MPR, 41TRPL3, Room ASH, Group P)
#   - 09:00-09:50 → Course PRD (Teacher ISW, SHT, Room JBJ, Group T)
#   - 09:00-09:50 → Course IMK (Teacher RIS, RDS, Room AGA, Group T)
#   - 10:00-10:50 → Course TA II (Teacher HER, 33TI2, Room ABS, Group P)
#   - 10:00-10:50 → Course ING IV (Teacher MPR, 32TK2, Room RSL, Group T)
#   - 10:00-10:50 → Course PA III (Teacher RIS, 43TRPL1, Room AFS, Group T)
#   - 10:00-10:50 → Course PNKI (Teacher TLG, 11TB, Room GPS, Group T)
#   - 10:00-10:50 → Course TEKNO (Teacher RIS, 44TRPL2, Room TAP, Group P)
#   - 10:00-10:50 → Course AKPL (Teacher VES, MEP, Room ASH, Group P)
#   - 10:00-10:50 → Course PROBSTAT (Teacher AMP, 42TRPL2, Room WMS, Group P)
#   - 10:00-10:50 → Course ALJALI (Teacher JUN, 12IF2, Room ADS, Group T)
#   - 10:00-10:50 → Course NRG (Teacher ISW, 12MR2, Room NSS, Group T)
#   - 10:00-10:50 → Course SM/SP (Teacher RIS, OPH, Room REG, Group P)
#   - 10:00-10:50 → Course MATDIS (Teacher AMP, YAG, Room ESS, Group P)
#   - 10:00-10:50 → Course SISOP (Teacher IPM, GIW, Room ACB, Group P)
#   - 10:00-10:50 → Course KESIS (Teacher SRT, JHS, Room BSS, Group T)
#   - 10:00-10:50 → Course SISTER (Teacher ESS, SFN, Room PAT, Group P)
#   - 11:00-11:50 → Course PBDSI (Teacher SGS, SEP, Room GHP, Group T)
#   - 11:00-11:50 → Course ADL (Teacher BSS, 13SI2, Room HTO, Group P)
#   - 11:00-11:50 → Course TEKNO (Teacher RIS, 44TRPL1, Room ASD, Group P)
#   - 11:00-11:50 → Course DETING (Teacher RIS, THL, Room HTS, Group T)
#   - 11:00-11:50 → Course CERTAN (Teacher GPS, DPL, Room GPS, Group T)
#   - 11:00-11:50 → Course ABD (Teacher GHP, RCH, Room AFS, Group T)
#   - 11:00-11:50 → Course PA III (Teacher RIS, 43TRPL2, Room SRT, Group T)
#   - 11:00-11:50 → Course MADAS II (Teacher REG, 11TM, Room FBA, Group T)
#   - 11:00-11:50 → Course KOMDAT (Teacher IPM, 33TK2, Room DPL, Group P)
#   - 11:00-11:50 → Course ENG II (Teacher RMS, 11TE1, Room HER, Group T)
#   - 11:00-11:50 → Course PM (Teacher ASD, RSL, Room AGA, Group P)
#   - 11:00-11:50 → Course SISOP (Teacher GIW, IRS, Room AMS, Group P)
#   - 11:00-11:50 → Course PP (Teacher NJT, MMK, Room NMA, Group T)
#   - 11:00-11:50 → Course AKPL (Teacher VES, MEP, Room TML, Group P)
#   - 11:00-11:50 → Course SISOP (Teacher IPM, GIW, Room GFP, Group P)
#   - 11:00-11:50 → Course ING II (Teacher MPR, 41TRPL3, Room RDP, Group P)
#   - 13:00-13:50 → Course ERP (Teacher PAT, SRT, Room RDS, Group T)
#   - 13:00-13:50 → Course MADAS II (Teacher REG, 11MR2, Room GDE, Group T)
#   - 13:00-13:50 → Course ENG III (Teacher MPR, 13IF1, Room VES, Group T)
#   - 13:00-13:50 → Course ADL (Teacher BSS, 13SI2, Room GPS, Group P)
#   - 13:00-13:50 → Course ERP (Teacher PAT, SRT, Room REG, Group T)
#   - 13:00-13:50 → Course TEKEU (Teacher WMS, 14MR1, Room RFK, Group T)
#   - 13:00-13:50 → Course TEK.NET (Teacher TAP, 32TI2, Room FST, Group P)
#   - 13:00-13:50 → Course ATI (Teacher RDP, 14MR2, Room AGA, Group T)
#   - 13:00-13:50 → Course PABI (Teacher MMS, MEP, Room ANA, Group P)
#   - 13:00-13:50 → Course SISTER (Teacher ESS, SFN, Room JUN, Group P)
#   - 14:00-14:50 → Course TA I (Teacher RDS, 14IF1, Room RIS, Group P)
#   - 14:00-14:50 → Course PAM (Teacher ADS, TAP, Room VES, Group P)
#   - 14:00-14:50 → Course ING IV (Teacher MPR, 32TI2, Room YUL, Group P)
#   - 14:00-14:50 → Course TERMO (Teacher MMK, 12TB, Room WMS, Group T)
#   - 14:00-14:50 → Course ING II (Teacher RMM, 31TI1, Room NMA, Group P)
#   - 14:00-14:50 → Course TA II (Teacher RDS, 14IF2, Room TML, Group P)
#   - 14:00-14:50 → Course ABD (Teacher GHP, RCH, Room RMS, Group T)
#   - 14:00-14:50 → Course ENG II (Teacher RMS, 11IF2, Room MMK, Group P)
#   - 14:00-14:50 → Course PBD (Teacher VES, AMS, Room MMM, Group P)
#   - 14:00-14:50 → Course PROG I (Teacher GFP, 11TE2, Room IPM, Group T)
#   - 14:00-14:50 → Course ALJALI (Teacher IFY, SML, Room AGA, Group P)
#   - 15:00-15:50 → Course ING II (Teacher RMM, 41TRPL1, Room TLG, Group P)
#   - 15:00-15:50 → Course PAM (Teacher ADS, TAP, Room ADS, Group T)
#   - 15:00-15:50 → Course TEKNO (Teacher RIS, 44TRPL3, Room TML, Group P)
#   - 15:00-15:50 → Course ENG II (Teacher RMS, 11TM, Room RDP, Group T)
#   - 15:00-15:50 → Course ELKA I (Teacher DPL, ARH, Room VES, Group P)
#   - 15:00-15:50 → Course PAM (Teacher ADS, TAP, Room HTO, Group T)
#   - 15:00-15:50 → Course MATDIS (Teacher AMP, 11SI2, Room WMS, Group T)
#   - 15:00-15:50 → Course SISOP (Teacher GIW, IRS, Room ABS, Group P)
#   - 15:00-15:50 → Course SISOP (Teacher IPM, GIW, Room ACB, Group P)
#   - 15:00-15:50 → Course PRD (Teacher SHT, JBJ, Room MPR, Group P)
#   - 15:00-15:50 → Course EPROF (Teacher DPL, 14TE1, Room ANA, Group P)
#   - 16:00-16:50 → Course TEKNO (Teacher RIS, 44TRPL2, Room MMM, Group T)
#   - 16:00-16:50 → Course PSW II (Teacher GHP, TAP, Room NSS, Group P)
#   - 16:00-16:50 → Course PRPL (Teacher AMS, 41TRPL3, Room SGS, Group P)
#   - 16:00-16:50 → Course PEMPROS (Teacher CHP, GFP, Room ADS, Group T)
#   - 16:00-16:50 → Course PAR (Teacher IHT, 11TE1, Room SML, Group T)
#   - 16:00-16:50 → Course PASTI (Teacher RCH, MAL, Room ABS, Group P)
#   - 16:00-16:50 → Course ATI (Teacher RDP, 14MR1, Room FBA, Group T)
#   - 16:00-16:50 → Course ALJALI (Teacher IFY, SML, Room RDS, Group P)
# ================================================================================
#
# ✅ Schedule successfully saved to 'optimized_schedule_Medium.csv'
#
# ================================================================================
# PROSES OPTIMISASI DAN EKSPOR JADWAL TELAH SELESAI (Kategori: Medium).
# ================================================================================
